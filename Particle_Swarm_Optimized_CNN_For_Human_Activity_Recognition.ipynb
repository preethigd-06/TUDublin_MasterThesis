# %% [markdown]
# #Particle Swarm Optimization of Convolutional Neural Networks for Human Activity Recognition
#
#
# <br>
#
# Activity Recognition aims at identifying the activity of users based on series of observations
# collected during the activity in a definite context environment. Applications
# that are enabled with activity recognition are gaining huge attention, as users get
# personalized services and support based on their contextual behaviour. The proliferation
# of wearable devices and smartphones has provided real-time monitoring of
# human activities through sensors that are embedded in smart devices such as proximity
# sensors, cameras, microphone, magnetometers accelerometers, gyroscopes, GPS
# etc., Thus, understanding human activities in inferring the gesture or position has
# created a competitive challenge in building personal health care systems, examining
#
# wellness and fit characteristics, and most pre-dominantly in elderly care, abnormal
# activity detection, diabetes or epilepsy disorders etc.
#
# ##Research Problem:
#
# Human Activity Recognition (HAR) is evolving to be a challenging time series classification task which involves predicting the human activity based on sensor data
# where the data points are recorded at regular intervals. Though HAR seems to be
# the straightforward approach of performing HAR, there are numerous issues and challenges
# that are encountered in selecting the appropriate feature processing technique
# and thus choosing the correct modelling algorithm for the time series data is crucial.
# Apart from this, there are also few resource constraints like limited battery power (due
# to continuous sampling on mobile devices), memory and storage capabilities.
# Thus, the conventional approaches have made extraordinary progress on Human
# Activity Recognition (HAR) by incorporating machine learning algorithms such as
# Naive Bayes, Decision Tree, Support Vector Machine, Logistic Regression as there are
# only few labelled data. It requires domain knowledge to manually process the feature
# extraction.
#
# On the other hand, deep learning algorithms has seen high performance
# in areas like Natural language Processing, Object Recognition etc.,
#
# In spite of these
# advancements, another line of research has emerged in applying nature-inspired meta
# heuristic optimization techniques like Particle Swarm Optimization, Genetic Algorithms
# on Neural Networks. The research question that is aimed to be addressed in
# the current study can be concisely stated as below
#
# {
# "To what extent can the Particle Swarm Optimized Convolutional Neural Network
# significantly enhance the recognition of human activity from raw inertial sensor data
# when compared with supervised machine learning algorithms and Deep Learning Algo-
# rithms" }
# ## AIM
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# ## Data Description
#
# The dataset used in this study is downloaded from UCI Machine Learning Repository created
# at SmartLab, one of the Research Laboratories at DIBRIS at University of Genova in Italy
# whose major research area follows investigating techniques and algorithms for Computational
# Intelligence and Data Analytics. (Anguita, 2006) experimented on a group of 30 volunteers
# within a range of age between 19-48 years who were performing daily activities. Each
# subject are volunteer performed daily activities which are show in Table 3.3 while carrying a
# smartphone (Samsung Galaxy S II) that is waist-mounted. The smartphone was embedded
# with inertial sensors.
#
#
# ## How data is collected
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Column names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Dataset Size :
# > 27 MB

# %% [markdown]
# #Overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Reserach Problem
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#/content/drive/My Drive/Human Activity Detection-Without Verbose .ipynb
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/4AGRV-WI9TJsqq6ORazIrHSrY2F242qiAUBkUB5tF7umhAluy6I70Uw
# Mounted at /content/gdrive

# %%
pip install tensorflow==1.14.0
# Out:
# Collecting tensorflow==1.14.0
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
#      |████████████████████████████████| 109.2MB 38kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.2.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.3.3)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.18.5)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 52.7MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.35.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.8.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.31.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 48.2MB/s
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 7.7MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (3.12.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (49.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (3.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14.0) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (3.1.0)
# Installing collected packages: tensorboard, tensorflow-estimator, keras-applications, tensorflow
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
pip install keras==2.3.1
# Out:
# Collecting keras==2.3.1
#   Downloading https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl (377kB)
#      |████████████████████████████████| 378kB 8.5MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.18.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.0.8)
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.3.1

# %%
pip install pandas==0.22.0
# Out:
# Collecting pandas==0.22.0
#   Downloading https://files.pythonhosted.org/packages/da/c6/0936bc5814b429fddb5d6252566fe73a3e40372e6ceaf87de3dec1326f28/pandas-0.22.0-cp36-cp36m-manylinux1_x86_64.whl (26.2MB)
#      |████████████████████████████████| 26.3MB 116kB/s
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas==0.22.0) (1.18.5)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas==0.22.0) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas==0.22.0) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas==0.22.0) (1.15.0)
# ERROR: xarray 0.15.1 has requirement pandas>=0.25, but you'll have pandas 0.22.0 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement pandas>=0.25.0, but you'll have pandas 0.22.0 which is incompatible.
# ERROR: mizani 0.6.0 has requirement pandas>=0.25.0, but you'll have pandas 0.22.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=1.0.0; python_version >= "3.0", but you'll have pandas 0.22.0 which is incompatible.
# ERROR: fbprophet 0.6 has requirement pandas>=0.23.4, but you'll have pandas 0.22.0 which is incompatible.
# Installing collected packages: pandas
#   Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
# Successfully installed pandas-0.22.0

# %%
pip install keras==2.3.1
# Out:
# Requirement already satisfied: keras==2.3.1 in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.18.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.1) (1.0.8)

# %% [markdown]
# ## Reserach Problem
#
#  + Given a new datapoint of activities we have to predict the Activity

# %%
import numpy as np
import pandas as pd
import warnings
import tensorflow as tf
warnings.filterwarnings("ignore")

# get the features from the file features.txt
features = list()
with open('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# No of Features: 561

# %%
print(tf.__version__)
print(pd.__version__)
# Out:
# 1.14.0
# 0.22.0

# %%
pip install pandas==0.22.0
# Out:
# Requirement already satisfied: pandas==0.22.0 in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas==0.22.0) (1.18.5)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas==0.22.0) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas==0.22.0) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas==0.22.0) (1.15.0)

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 3814           0.273891          -0.026103          -0.099049
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 3814         -0.996195         -0.935845         -0.976529         -0.996847
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X      ...       \
# 3814         -0.941131         -0.976223         -0.942221      ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 3814                    -0.028718                             -0.033536
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 3814                         -0.779548                              -0.93013
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 3814              -0.80726              0.192944             -0.079639
#
#       subject  Activity  ActivityName
# 3814       19         5      STANDING
#
# [1 rows x 564 columns]

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2631           0.280006          -0.022478          -0.093702
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2631         -0.995021         -0.991688         -0.992725         -0.996207
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X      ...       \
# 2631         -0.990821         -0.993815         -0.937393      ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 2631                     0.001942                              0.197782
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 2631                          -0.10252                             -0.013457
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 2631             -0.869565              0.005294              0.032352
#
#       subject  Activity  ActivityName
# 2631       24         4       SITTING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %%
train.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity',
#        'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects
#
# > Indented block

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '_')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAcc_mean_X', 'tBodyAcc_mean_Y', 'tBodyAcc_mean_Z',
#        'tBodyAcc_std_X', 'tBodyAcc_std_Y', 'tBodyAcc_std_Z', 'tBodyAcc_mad_X',
#        'tBodyAcc_mad_Y', 'tBodyAcc_mad_Z', 'tBodyAcc_max_X',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/csv_files/train.csv', index=False)
test.to_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMag_mean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,14), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities')
sns.distplot(df4['tBodyAccMag_mean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMag_mean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMag_mean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMag_mean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMag_mean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMag_mean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMag_mean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ## Obtain the train and test data

# %%
train = pd.read_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/csv_files/train.csv')
test = pd.read_csv('/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
train.head(1)
# Out:
#    tBodyAcc_mean_X  tBodyAcc_mean_Y  tBodyAcc_mean_Z  tBodyAcc_std_X  \
# 0         0.288585        -0.020294        -0.132905       -0.995279
#
#    tBodyAcc_std_Y  tBodyAcc_std_Z  tBodyAcc_mad_X  tBodyAcc_mad_Y  \
# 0       -0.983111       -0.913526       -0.995112       -0.983185
#
#    tBodyAcc_mad_Z  tBodyAcc_max_X      ...       angletBodyAccMeangravity  \
# 0       -0.923527       -0.934724      ...                      -0.112754
#
#    angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# 0                            0.0304                      -0.464761
#
#    angletBodyGyroJerkMeangravityMean  angleXgravityMean  angleYgravityMean  \
# 0                          -0.018446          -0.841247           0.179941
#
#    angleZgravityMean  subject  Activity  ActivityName
# 0          -0.058627        1         5      STANDING
#
# [1 rows x 564 columns]

# %%
# get X_train and y_train from csv files
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

# %%
# get X_test and y_test from test csv file
X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

# %%
print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 561),(7352,))
# X_test  and y_test  : ((2947, 561),(2947,))

# %% [markdown]
# # Modeling with the data

# %% [markdown]
# ### Labels that are useful in plotting confusion matrix

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %% [markdown]
# ### Function to plot the confusion matrix

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import GridSearchCV

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix Here',
                          cmap=plt.cm.Purples):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### Generic function to run any model specified

# %%
from datetime import datetime
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=False, \
                 print_cm=True, cm_cmap=plt.cm.BuPu):
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X_train, y_train)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    f1_score = metrics.f1_score(y_true=y_test, y_pred=y_pred, average ='weighted' )
    # store accuracy in results
    results['accuracy'] = accuracy
    results['f1-score'] = f1_score
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    print('coming here to plot')
    plot_confusion_matrix(cm, classes=class_labels, normalize=False, title='confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %% [markdown]
# ### Method to print the gridsearch Attributes

# %%
def print_grid_search_attributes(model):
    # Estimator that gave highest score among all the estimators formed in GridSearch
    print('--------------------------')
    print('|      Best Estimator     |')
    print('--------------------------')
    print('\n\t{}\n'.format(model.best_estimator_))


    # parameters that gave best results while performing grid search
    print('--------------------------')
    print('|     Best parameters     |')
    print('--------------------------')
    print('\tParameters of best estimator : \n\n\t{}\n'.format(model.best_params_))


    #  number of cross validation splits
    print('---------------------------------')
    print('|   No of CrossValidation sets   |')
    print('--------------------------------')
    print('\n\tTotal numbre of cross validation sets: {}\n'.format(model.n_splits_))


    # Average cross validated score of the best estimator, from the Grid Search 
    print('--------------------------')
    print('|        Best Score       |')
    print('--------------------------')
    print('\n\tAverage Cross Validate scores of best estimator : \n\n\t{}\n'.format(model.best_score_))

# %% [markdown]
# **bold text**
#
# #PART 1:
# #Machine Learning Algorithms - with Hand-crafted features -Version 1
#
# ## 1. Naive Byes

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model_results = perform_model(nb_model, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:00.065410
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.054767
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.7702748557855447
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[323 211   0   0   0   3]
#  [  5 368 111   0   0   7]
#  [  8  54 455   0   0  15]
#  [  0   0   0 416  42  38]
#  [  0   0   0  80 257  83]
#  [  0   0   0   9  11 451]]
# coming here to plot
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       0.96      0.60      0.74       537
#            SITTING       0.58      0.75      0.65       491
#           STANDING       0.80      0.86      0.83       532
#            WALKING       0.82      0.84      0.83       496
# WALKING_DOWNSTAIRS       0.83      0.61      0.70       420
#   WALKING_UPSTAIRS       0.76      0.96      0.84       471
#
#           accuracy                           0.77      2947
#          macro avg       0.79      0.77      0.77      2947
#       weighted avg       0.79      0.77      0.77      2947

# %% [markdown]
# # 2. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model_results = perform_model(rf_model, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:10.800249
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.052845
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9263657957244655
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 436  55   0   0   0]
#  [  0  43 489   0   0   0]
#  [  0   0   0 481   8   7]
#  [  0   0   0  19 357  44]
#  [  0   0   0  34   7 430]]
# coming here to plot
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.91      0.89      0.90       491
#           STANDING       0.90      0.92      0.91       532
#            WALKING       0.90      0.97      0.93       496
# WALKING_DOWNSTAIRS       0.96      0.85      0.90       420
#   WALKING_UPSTAIRS       0.89      0.91      0.90       471
#
#           accuracy                           0.93      2947
#          macro avg       0.93      0.92      0.92      2947
#       weighted avg       0.93      0.93      0.93      2947

# %% [markdown]
# # 3. Linear Support Vector Machine

# %%
from sklearn.svm import SVC

svm_model = SVC()
svm_model_results = perform_model(svm_model, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:05.581796
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:04.896228
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9504580929759077
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 438  51   0   0   2]
#  [  0  29 503   0   0   0]
#  [  0   0   0 488   3   5]
#  [  0   0   0  10 384  26]
#  [  0   0   0  20   0 451]]
# coming here to plot
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.94      0.89      0.91       491
#           STANDING       0.91      0.95      0.93       532
#            WALKING       0.94      0.98      0.96       496
# WALKING_DOWNSTAIRS       0.99      0.91      0.95       420
#   WALKING_UPSTAIRS       0.93      0.96      0.94       471
#
#           accuracy                           0.95      2947
#          macro avg       0.95      0.95      0.95      2947
#       weighted avg       0.95      0.95      0.95      2947

# %% [markdown]
# # 4. Comparing Perfromance of Machine Learning Models

# %%
print('\n   Model              Accuracy    Error')
print('-----------------------------------------')
print('Gaussian Naive Byes  : {:.04}%     {:.04}% '.format(nb_model_results['accuracy'] * 100,
                                                                  100-(nb_model_results['accuracy'] * 100)))

print('Random Forest        : {:.04}%      {:.03}% '.format(rf_model_results['accuracy'] * 100,\
                                                          
                                                          100-(rf_model_results['accuracy'] * 100)))

print('Linear SVM           : {:.04}%      {:.03}% '.format(svm_model_results['accuracy'] * 100,\
                                                        
                                                        100-(svm_model_results['accuracy'] * 100)))
# Out:
#    Model              Accuracy    Error
# -----------------------------------------
# Gaussian Naive Byes  : 77.03%     22.97%
# Random Forest        : 92.64%      7.36%
# Linear SVM           : 95.05%      4.95%

# %% [markdown]
# # PART 2
# # Deep Learning Algorithms - With Raw Inertial Signals- Version 2
#
#
# Model  1 - Using LSTM
# Model  2 - Using CNN
# Model 3 - PSO-CNN

# %% [markdown]
# # 1. Long Short Term Memory (LSTM)

# %%
# Importing libraries
import numpy as np
import pandas as pd
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# Activities are the class labels
# It is a 6 class classification
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])

# %%
# Data directory
DATADIR = '/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset'
# Raw data signals
# Signals are from Accelerometer and Gyroscope
# The signals are in x,y,z directions
# Sensor signals are filtered to have only body acceleration
# excluding the acceleration due to gravity
# Triaxial acceleration from the accelerometer is total acceleration
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
# Utility function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = f'/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/{subset}/Inertial Signals/{signal}_{subset}.txt'
        signals_data.append(
            _read_csv(filename).as_matrix()
        ) 

    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

# %%
def load_y(subset):
    """
    The objective that we are trying to predict is a integer, from 1 to 6,
    that represents a human activity. We return a binary representation of 
    every sample objective as a 6 bits vector using One Hot Encoding
    (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
    """
    filename = f'/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/{subset}/y_{subset}.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).as_matrix()

# %%
def load_data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, y_train, X_test,  y_test

# %%
# Importing tensorflow
np.random.seed(42)
import tensorflow as tf
#tf.random.set_seed(36)

# %%
# Importing libraries
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout

# %%
# Initializing parameters
epochs = 30
batch_size = 16
n_hidden = 32

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Loading the train and test data
X_train, Y_train, X_test,  Y_test = load_data()

# %%
X_train.shape,Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((7352, 128, 9), (7352, 6), (2947, 128, 9), (2947, 6))

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)
#n_classes  = 6
print(timesteps)
print(input_dim)
print(len(X_train))
print(n_classes)
# Out:
# 128
# 9
# 7352
# 6

# %% [markdown]
# #### Base Model

# %%
# Initiliazing the sequential model
LSTMmodel = Sequential()
# Configuring the parameters
LSTMmodel.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
LSTMmodel.add(Dropout(0.5))
#LSTMmodel.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
LSTMmodel.add(Dropout(0.6))
# Adding a dense output layer with sigmoid activation
LSTMmodel.add(Dense(n_classes, activation='sigmoid'))
LSTMmodel.summary()
# Out:
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 32)                5376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
LSTMmodel.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Training the model
historyLSTMmodel = LSTMmodel.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=30)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 1.4586 - accuracy: 0.3972 - val_loss: 1.2458 - val_accuracy: 0.4449
# Epoch 2/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 1.2233 - accuracy: 0.4771 - val_loss: 1.1664 - val_accuracy: 0.4625
# Epoch 3/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 1.1210 - accuracy: 0.5027 - val_loss: 1.0087 - val_accuracy: 0.5816
# Epoch 4/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.9705 - accuracy: 0.5702 - val_loss: 1.1230 - val_accuracy: 0.5887
# Epoch 5/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.9061 - accuracy: 0.6038 - val_loss: 0.8538 - val_accuracy: 0.5993
# Epoch 6/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.8382 - accuracy: 0.6221 - val_loss: 0.8385 - val_accuracy: 0.6108
# Epoch 7/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.8238 - accuracy: 0.6189 - val_loss: 0.9494 - val_accuracy: 0.6020
# Epoch 8/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.8972 - accuracy: 0.5990 - val_loss: 1.0888 - val_accuracy: 0.5480
# Epoch 9/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.8134 - accuracy: 0.6196 - val_loss: 0.8300 - val_accuracy: 0.6128
# Epoch 10/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.7924 - accuracy: 0.6280 - val_loss: 0.8425 - val_accuracy: 0.6166
# Epoch 11/30
# 7352/7352 [==============================] - 16s 2ms/step - loss: 0.7696 - accuracy: 0.6280 - val_loss: 0.8372 - val_accuracy: 0.6179
# Epoch 12/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.7627 - accuracy: 0.6322 - val_loss: 0.8180 - val_accuracy: 0.6159
# Epoch 13/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.7792 - accuracy: 0.6234 - val_loss: 0.8683 - val_accuracy: 0.6135
# Epoch 14/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.7718 - accuracy: 0.6342 - val_loss: 0.8718 - val_accuracy: 0.6152
# Epoch 15/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.8229 - accuracy: 0.6289 - val_loss: 0.8452 - val_accuracy: 0.6162
# Epoch 16/30
# 7352/7352 [==============================] - 16s 2ms/step - loss: 0.8314 - accuracy: 0.6285 - val_loss: 0.8151 - val_accuracy: 0.6261
# Epoch 17/30
# 7352/7352 [==============================] - 16s 2ms/step - loss: 0.7563 - accuracy: 0.6416 - val_loss: 0.8292 - val_accuracy: 0.6318
# Epoch 18/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.7673 - accuracy: 0.6511 - val_loss: 0.8096 - val_accuracy: 0.6641
# Epoch 19/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.7674 - accuracy: 0.6586 - val_loss: 0.7853 - val_accuracy: 0.6644
# Epoch 20/30
# 7352/7352 [==============================] - 16s 2ms/step - loss: 0.7095 - accuracy: 0.6693 - val_loss: 0.7769 - val_accuracy: 0.6817
# Epoch 21/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.6999 - accuracy: 0.6876 - val_loss: 0.7873 - val_accuracy: 0.6654
# Epoch 22/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.6817 - accuracy: 0.6902 - val_loss: 0.7892 - val_accuracy: 0.6831
# Epoch 23/30
# 7352/7352 [==============================] - 16s 2ms/step - loss: 0.6766 - accuracy: 0.7043 - val_loss: 0.6791 - val_accuracy: 0.6943
# Epoch 24/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.6424 - accuracy: 0.7316 - val_loss: 0.6871 - val_accuracy: 0.7913
# Epoch 25/30
# 7352/7352 [==============================] - 16s 2ms/step - loss: 0.5809 - accuracy: 0.7754 - val_loss: 0.6369 - val_accuracy: 0.8263
# Epoch 26/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.5415 - accuracy: 0.8028 - val_loss: 0.6134 - val_accuracy: 0.8283
# Epoch 27/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.5203 - accuracy: 0.8237 - val_loss: 0.6006 - val_accuracy: 0.8324
# Epoch 28/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.4921 - accuracy: 0.8357 - val_loss: 0.5836 - val_accuracy: 0.8561
# Epoch 29/30
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.4722 - accuracy: 0.8400 - val_loss: 0.5891 - val_accuracy: 0.8402
# Epoch 30/30
# 7352/7352 [==============================] - 16s 2ms/step - loss: 0.4595 - accuracy: 0.8483 - val_loss: 0.6004 - val_accuracy: 0.8463

# %%
# plot accuracy during training
pyplot.subplot(211)
pyplot.title('Accuracy')
pyplot.plot(historyLSTMmodel.history['accuracy'], label='train accuracy')
pyplot.plot(historyLSTMmodel.history['val_accuracy'], label='test accuracy')
pyplot.xlabel('No of Epochs')
pyplot.ylabel('Accuracy')
pyplot.legend()
pyplot.show()

# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Loss')
pyplot.plot(historyLSTMmodel.history['loss'], label='train loss')
pyplot.plot(historyLSTMmodel.history['val_loss'], label='test loss')
pyplot.xlabel('No of Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()

# %%
# evaluate the model
_, train_acc = LSTMmodel.evaluate(X_train, Y_train, verbose=0)
_, test_acc = LSTMmodel.evaluate(X_test, Y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.933, Test: 0.846

# %%
plt.figure(figsize=(8,8))
      
cm = confusion_matrix_rnn(Y_test, LSTMmodel.predict(X_test))
plot_confusion_matrix(cm, classes=labels, normalize=False, title='confusion matrix', cmap = plt.cm.BuPu)
plt.show()

# %%
y_pred = LSTMmodel.predict_classes(X_test)

y_test =Y_val.argmax(axis=-1)
print(classification_report(y_test, y_pred, target_names=['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']))
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.90      0.68      0.77       496
#      Jogging       0.77      0.91      0.83       471
#      Sitting       0.81      0.98      0.89       420
#     Standing       0.80      0.78      0.79       491
#     Upstairs       0.82      0.80      0.81       532
#      Walking       1.00      0.95      0.97       537
#
#     accuracy                           0.85      2947
#    macro avg       0.85      0.85      0.84      2947
# weighted avg       0.85      0.85      0.84      2947

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %% [markdown]
# # 1.1 Multi layer LSTM

# %%
# Initiliazing the sequential model
MultiLSTMmodel = Sequential()
# Configuring the parameters
MultiLSTMmodel.add(LSTM(32,return_sequences=True,input_shape=(timesteps, input_dim)))
# Adding a dropout layer
MultiLSTMmodel.add(Dropout(0.5))

MultiLSTMmodel.add(LSTM(28,input_shape=(timesteps, input_dim)))
# Adding a dropout layer
MultiLSTMmodel.add(Dropout(0.8))
# Adding a dense output layer with sigmoid activation
MultiLSTMmodel.add(Dense(n_classes, activation='sigmoid'))
print('************Multi Layer LSTM**************')
MultiLSTMmodel.summary()
# Out:
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# ************Multi Layer LSTM**************
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128, 32)           5376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 32)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 28)                6832
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 174
# =================================================================
# Total params: 12,382
# Trainable params: 12,382
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
MultiLSTMmodel.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Training the model
MultiLSTMmodelhistory = MultiLSTMmodel.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=epochs)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 1.3843 - accuracy: 0.4377 - val_loss: 1.0110 - val_accuracy: 0.5959
# Epoch 2/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 1.0414 - accuracy: 0.5604 - val_loss: 0.8375 - val_accuracy: 0.6685
# Epoch 3/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.9228 - accuracy: 0.5860 - val_loss: 0.7749 - val_accuracy: 0.6037
# Epoch 4/30
# 7352/7352 [==============================] - 43s 6ms/step - loss: 0.8871 - accuracy: 0.5970 - val_loss: 0.7382 - val_accuracy: 0.6084
# Epoch 5/30
# 7352/7352 [==============================] - 43s 6ms/step - loss: 0.8529 - accuracy: 0.6036 - val_loss: 0.7474 - val_accuracy: 0.6240
# Epoch 6/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.8496 - accuracy: 0.6201 - val_loss: 0.7354 - val_accuracy: 0.6179
# Epoch 7/30
# 7352/7352 [==============================] - 43s 6ms/step - loss: 0.8367 - accuracy: 0.6175 - val_loss: 0.7542 - val_accuracy: 0.6301
# Epoch 8/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.8115 - accuracy: 0.6281 - val_loss: 0.7759 - val_accuracy: 0.6271
# Epoch 9/30
# 7352/7352 [==============================] - 43s 6ms/step - loss: 0.8071 - accuracy: 0.6264 - val_loss: 0.7505 - val_accuracy: 0.6183
# Epoch 10/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.7926 - accuracy: 0.6280 - val_loss: 0.7678 - val_accuracy: 0.6189
# Epoch 11/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.7730 - accuracy: 0.6412 - val_loss: 0.7324 - val_accuracy: 0.6159
# Epoch 12/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.7564 - accuracy: 0.6515 - val_loss: 0.7783 - val_accuracy: 0.6220
# Epoch 13/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.7732 - accuracy: 0.6756 - val_loss: 0.6854 - val_accuracy: 0.7248
# Epoch 14/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.6816 - accuracy: 0.7232 - val_loss: 0.6733 - val_accuracy: 0.7394
# Epoch 15/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.6278 - accuracy: 0.7412 - val_loss: 0.5597 - val_accuracy: 0.7533
# Epoch 16/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.5859 - accuracy: 0.7440 - val_loss: 0.5234 - val_accuracy: 0.7553
# Epoch 17/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.5764 - accuracy: 0.7466 - val_loss: 0.6624 - val_accuracy: 0.7469
# Epoch 18/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.6118 - accuracy: 0.7466 - val_loss: 2.3753 - val_accuracy: 0.5514
# Epoch 19/30
# 7352/7352 [==============================] - 43s 6ms/step - loss: 0.5826 - accuracy: 0.7465 - val_loss: 0.6143 - val_accuracy: 0.7475
# Epoch 20/30
# 7352/7352 [==============================] - 41s 6ms/step - loss: 0.5444 - accuracy: 0.7492 - val_loss: 0.6725 - val_accuracy: 0.7547
# Epoch 21/30
# 7352/7352 [==============================] - 41s 6ms/step - loss: 0.5538 - accuracy: 0.7583 - val_loss: 0.6727 - val_accuracy: 0.7553
# Epoch 22/30
# 7352/7352 [==============================] - 40s 6ms/step - loss: 0.5413 - accuracy: 0.7526 - val_loss: 0.6746 - val_accuracy: 0.7435
# Epoch 23/30
# 7352/7352 [==============================] - 41s 6ms/step - loss: 0.5325 - accuracy: 0.7572 - val_loss: 0.6847 - val_accuracy: 0.7499
# Epoch 24/30
# 7352/7352 [==============================] - 41s 6ms/step - loss: 0.5363 - accuracy: 0.7650 - val_loss: 0.6142 - val_accuracy: 0.7570
# Epoch 25/30
# 7352/7352 [==============================] - 43s 6ms/step - loss: 0.5278 - accuracy: 0.7654 - val_loss: 0.6542 - val_accuracy: 0.7523
# Epoch 26/30
# 7352/7352 [==============================] - 42s 6ms/step - loss: 0.5043 - accuracy: 0.7791 - val_loss: 0.6334 - val_accuracy: 0.8751
# Epoch 27/30
# 7352/7352 [==============================] - 41s 6ms/step - loss: 0.4753 - accuracy: 0.8017 - val_loss: 0.6515 - val_accuracy: 0.8677
# Epoch 28/30
# 7352/7352 [==============================] - 39s 5ms/step - loss: 0.4865 - accuracy: 0.8183 - val_loss: 0.5853 - val_accuracy: 0.8890
# Epoch 29/30
# 7352/7352 [==============================] - 39s 5ms/step - loss: 0.4505 - accuracy: 0.8434 - val_loss: 0.5884 - val_accuracy: 0.8755
# Epoch 30/30
# 7352/7352 [==============================] - 40s 5ms/step - loss: 0.4932 - accuracy: 0.8394 - val_loss: 0.6493 - val_accuracy: 0.8707

# %%
# plot accuracy during training
pyplot.subplot(211)
pyplot.title('Accuracy')
pyplot.plot(MultiLSTMmodelhistory.history['accuracy'], label='train accuracy')
pyplot.plot(MultiLSTMmodelhistory.history['val_accuracy'], label='test accuracy')
pyplot.xlabel('No of Epochs')
pyplot.ylabel('Accuracy')
pyplot.legend()
pyplot.show()

# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Loss')
pyplot.plot(MultiLSTMmodelhistory.history['loss'], label='train loss')
pyplot.plot(MultiLSTMmodelhistory.history['val_loss'], label='test loss')
pyplot.xlabel('No of Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()

# %%
# evaluate the model
_, train_acc = MultiLSTMmodel.evaluate(X_train, Y_train, verbose=0)
_, test_acc = MultiLSTMmodel.evaluate(X_test, Y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.942, Test: 0.871

# %%
plt.figure(figsize=(8,8))
      
cm = confusion_matrix_rnn(Y_test, MultiLSTMmodel.predict(X_test))
plot_confusion_matrix(cm, classes=labels, normalize=False, title='confusion matrix', cmap = plt.cm.BuPu)
plt.show()

# %%
y_pred = MultiLSTMmodel.predict_classes(X_test)

y_test =Y_test.argmax(axis=-1)
print(classification_report(y_test, y_pred, target_names=['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']))
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.87      0.92      0.89       496
#      Jogging       0.92      0.85      0.89       471
#      Sitting       0.87      0.85      0.86       420
#     Standing       0.79      0.84      0.81       491
#     Upstairs       0.81      0.81      0.81       532
#      Walking       0.98      0.95      0.97       537
#
#     accuracy                           0.87      2947
#    macro avg       0.87      0.87      0.87      2947
# weighted avg       0.87      0.87      0.87      2947

# %%
# Importing tensorflow
np.random.seed(36)
import tensorflow as tf
#tf.random.set_seed(36)

# %%
# Importing libraries
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout
from hyperopt import Trials, STATUS_OK, tpe
#from hyperas import optim
#from hyperas.distributions import choice, uniform
#from hyperas.utils import eval_hyperopt_space

# %%
pip install hyperas

# %%
##gives train and validation data 
def data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    # Data directory
    DATADIR = '/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/'
    # Raw data signals
    # Signals are from Accelerometer and Gyroscope
    # The signals are in x,y,z directions
    # Sensor signals are filtered to have only body acceleration
    # excluding the acceleration due to gravity
    # Triaxial acceleration from the accelerometer is total acceleration
    SIGNALS = [
        "body_acc_x",
        "body_acc_y",
        "body_acc_z",
        "body_gyro_x",
        "body_gyro_y",
        "body_gyro_z",
        "total_acc_x",
        "total_acc_y",
        "total_acc_z"
        ]
    # Utility function to read the data from csv file
    def _read_csv(filename):
        return pd.read_csv(filename, delim_whitespace=True, header=None)

    # Utility function to load the load
    def load_signals(subset):
        signals_data = []

        for signal in SIGNALS:
            filename = f'/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/{subset}/Inertial Signals/{signal}_{subset}.txt'
            signals_data.append( _read_csv(filename).as_matrix()) 

        # Transpose is used to change the dimensionality of the output,
        # aggregating the signals by combination of sample/timestep.
        # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
        return np.transpose(signals_data, (1, 2, 0))
    
    def load_y(subset):
        """
        The objective that we are trying to predict is a integer, from 1 to 6,
        that represents a human activity. We return a binary representation of 
        every sample objective as a 6 bits vector using One Hot Encoding
        (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
        """
        filename = f'/content/gdrive/My Drive/UCI HAR Dataset/UCI HAR Dataset/{subset}/y_{subset}.txt'
        y = _read_csv(filename)[0]
        return pd.get_dummies(y).as_matrix()
    
    X_train, X_val = load_signals('train'), load_signals('test')
    Y_train, Y_val = load_y('train'), load_y('test')

    return X_train, Y_train, X_val,  Y_val

# %%
pip install --upgrade hyperopt

# %%
from keras.regularizers import l2
import keras

# %%
# Activities are the class labels
# It is a 6 class classification
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

# Utility function to print the confusion matrix
def confusion_matrix_rnn(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    #return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])
    return metrics.confusion_matrix(Y_true, Y_pred)

# %% [markdown]
# ## 2. Using CNN

# %%
import os
os.environ['PYTHONHASHSEED'] = '0'
import numpy as np
import tensorflow as tf
import random as rn
np.random.seed(36)
rn.seed(36)
#tf.random.set_seed(36)
# Force TensorFlow to use single thread.
# Multiple threads are a potential source of non-reproducible results.
# For further details, see: https://stackoverflow.com/questions/42022950/
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,
                              inter_op_parallelism_threads=1)

from keras import backend as K

# The below tf.set_random_seed() will make random number generation
# in the TensorFlow backend have a well-defined initial state.
# For further details, see:
# https://www.tensorflow.org/api_docs/python/tf/set_random_seed

#tf.set_random_seed(36)
#tf.random.set_seed(36)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %%
# Importing libraries
import pandas as pd
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout

# %%
X_train, Y_train, X_val, Y_val = data()

# %%
X_train.shape, Y_train.shape, X_val.shape, Y_val.shape
# Out:
# ((7352, 128, 9), (7352, 6), (2947, 128, 9), (2947, 6))

# %%
X_train.shape,Y_train.shape,X_val.shape, Y_val.shape
# Out:
# ((7352, 128, 9), (7352, 6), (2947, 128, 9), (2947, 6))

# %%
###Scaling data
from sklearn.base import BaseEstimator, TransformerMixin
class scaling_tseries_data(BaseEstimator, TransformerMixin):
    from sklearn.preprocessing import StandardScaler
    def __init__(self):
        self.scale = None

    def transform(self, X):
        temp_X1 = X.reshape((X.shape[0] * X.shape[1], X.shape[2]))
        temp_X1 = self.scale.transform(temp_X1)
        return temp_X1.reshape(X.shape)

    def fit(self, X):
        # remove overlaping
        remove = int(X.shape[1] / 2)
        temp_X = X[:, -remove:, :]
        # flatten data
        temp_X = temp_X.reshape((temp_X.shape[0] * temp_X.shape[1], temp_X.shape[2]))
        scale = StandardScaler()
        scale.fit(temp_X)
        self.scale = scale
        return self

# %%
Scale = scaling_tseries_data()
Scale.fit(X_train)
X_train_sc = Scale.transform(X_train)
X_val_sc = Scale.transform(X_val)

# %%
print('Shape of scaled X train',X_train_sc.shape)
print('Shape of scaled X test',X_val_sc.shape)
# Out:
# Shape of scaled X train (7352, 128, 9)
# Shape of scaled X test (2947, 128, 9)

# %% [markdown]
# #### Base Model

# %%
CNNmodel = Sequential()
CNNmodel.add(Conv1D(filters=32, kernel_size=3, activation='relu',kernel_initializer='he_uniform',input_shape=(128,9)))
CNNmodel.add(Conv1D(filters=32, kernel_size=3, activation='relu',kernel_initializer='he_uniform'))
CNNmodel.add(Dropout(0.6))
CNNmodel.add(MaxPooling1D(pool_size=2))
CNNmodel.add(Flatten())
CNNmodel.add(Dense(50, activation='relu'))
CNNmodel.add(Dense(6, activation='softmax'))
CNNmodel.summary()
# Out:
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 126, 32)           896
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 124, 32)           3104
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 124, 32)           0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 62, 32)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1984)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                99250
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 306
# =================================================================
# Total params: 103,556
# Trainable params: 103,556
# Non-trainable params: 0
# _________________________________________________________________

# %%
CNNmodel.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
CNNmodelHistory = CNNmodel.fit(X_train_sc,Y_train, epochs=30, batch_size=16,validation_data=(X_val_sc, Y_val), verbose=1)
# Out:
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/30
# 7352/7352 [==============================] - 4s 585us/step - loss: 0.4396 - accuracy: 0.8279 - val_loss: 0.3727 - val_accuracy: 0.8938
# Epoch 2/30
# 7352/7352 [==============================] - 4s 559us/step - loss: 0.1458 - accuracy: 0.9376 - val_loss: 0.3481 - val_accuracy: 0.9067
# Epoch 3/30
# 7352/7352 [==============================] - 4s 551us/step - loss: 0.1090 - accuracy: 0.9514 - val_loss: 0.3367 - val_accuracy: 0.9053
# Epoch 4/30
# 7352/7352 [==============================] - 4s 548us/step - loss: 0.1169 - accuracy: 0.9506 - val_loss: 0.3278 - val_accuracy: 0.9162
# Epoch 5/30
# 7352/7352 [==============================] - 4s 547us/step - loss: 0.0958 - accuracy: 0.9557 - val_loss: 0.3523 - val_accuracy: 0.9097
# Epoch 6/30
# 7352/7352 [==============================] - 4s 544us/step - loss: 0.0920 - accuracy: 0.9551 - val_loss: 0.3986 - val_accuracy: 0.9141
# Epoch 7/30
# 7352/7352 [==============================] - 4s 546us/step - loss: 0.0840 - accuracy: 0.9611 - val_loss: 0.4747 - val_accuracy: 0.9094
# Epoch 8/30
# 7352/7352 [==============================] - 4s 545us/step - loss: 0.0801 - accuracy: 0.9622 - val_loss: 0.4182 - val_accuracy: 0.9067
# Epoch 9/30
# 7352/7352 [==============================] - 4s 539us/step - loss: 0.0814 - accuracy: 0.9635 - val_loss: 0.6201 - val_accuracy: 0.8836
# Epoch 10/30
# 7352/7352 [==============================] - 4s 542us/step - loss: 0.0662 - accuracy: 0.9687 - val_loss: 0.4778 - val_accuracy: 0.8975
# Epoch 11/30
# 7352/7352 [==============================] - 4s 540us/step - loss: 0.0654 - accuracy: 0.9712 - val_loss: 0.3972 - val_accuracy: 0.9053
# Epoch 12/30
# 7352/7352 [==============================] - 4s 534us/step - loss: 0.0611 - accuracy: 0.9729 - val_loss: 0.5366 - val_accuracy: 0.8972
# Epoch 13/30
# 7352/7352 [==============================] - 4s 529us/step - loss: 0.0727 - accuracy: 0.9708 - val_loss: 0.5287 - val_accuracy: 0.9033
# Epoch 14/30
# 7352/7352 [==============================] - 4s 531us/step - loss: 0.0576 - accuracy: 0.9746 - val_loss: 0.5070 - val_accuracy: 0.9063
# Epoch 15/30
# 7352/7352 [==============================] - 4s 533us/step - loss: 0.0623 - accuracy: 0.9740 - val_loss: 0.6104 - val_accuracy: 0.9013
# Epoch 16/30
# 7352/7352 [==============================] - 4s 530us/step - loss: 0.0475 - accuracy: 0.9770 - val_loss: 0.5133 - val_accuracy: 0.9067
# Epoch 17/30
# 7352/7352 [==============================] - 4s 538us/step - loss: 0.0507 - accuracy: 0.9767 - val_loss: 0.5562 - val_accuracy: 0.9023
# Epoch 18/30
# 7352/7352 [==============================] - 4s 533us/step - loss: 0.0470 - accuracy: 0.9786 - val_loss: 0.6804 - val_accuracy: 0.8894
# Epoch 19/30
# 7352/7352 [==============================] - 4s 530us/step - loss: 0.0483 - accuracy: 0.9796 - val_loss: 0.5828 - val_accuracy: 0.9087
# Epoch 20/30
# 7352/7352 [==============================] - 4s 547us/step - loss: 0.0644 - accuracy: 0.9774 - val_loss: 0.4950 - val_accuracy: 0.9097
# Epoch 21/30
# 7352/7352 [==============================] - 4s 537us/step - loss: 0.0413 - accuracy: 0.9812 - val_loss: 0.5271 - val_accuracy: 0.9094
# Epoch 22/30
# 7352/7352 [==============================] - 4s 538us/step - loss: 0.0409 - accuracy: 0.9804 - val_loss: 0.4993 - val_accuracy: 0.9128
# Epoch 23/30
# 7352/7352 [==============================] - 4s 539us/step - loss: 0.0419 - accuracy: 0.9816 - val_loss: 0.6217 - val_accuracy: 0.8972
# Epoch 24/30
# 7352/7352 [==============================] - 4s 563us/step - loss: 0.0416 - accuracy: 0.9839 - val_loss: 0.5473 - val_accuracy: 0.9128
# Epoch 25/30
# 7352/7352 [==============================] - 4s 558us/step - loss: 0.0356 - accuracy: 0.9845 - val_loss: 0.7449 - val_accuracy: 0.8863
# Epoch 26/30
# 7352/7352 [==============================] - 4s 543us/step - loss: 0.0372 - accuracy: 0.9857 - val_loss: 0.5698 - val_accuracy: 0.9111
# Epoch 27/30
# 7352/7352 [==============================] - 4s 529us/step - loss: 0.0338 - accuracy: 0.9852 - val_loss: 0.5443 - val_accuracy: 0.9114
# Epoch 28/30
# 7352/7352 [==============================] - 4s 528us/step - loss: 0.0347 - accuracy: 0.9850 - val_loss: 0.5548 - val_accuracy: 0.9016
# Epoch 29/30
# 7352/7352 [==============================] - 4s 522us/step - loss: 0.0366 - accuracy: 0.9878 - val_loss: 0.5944 - val_accuracy: 0.9043
# Epoch 30/30
# 7352/7352 [==============================] - 4s 520us/step - loss: 0.0414 - accuracy: 0.9848 - val_loss: 0.8319 - val_accuracy: 0.8982

# %% [markdown]
# it is giving some good score in train as well as test but it is overfitting so much. i will try some regularization in below models.

# %%
# plot accuracy during training
pyplot.subplot(211)
pyplot.title('Accuracy')
pyplot.plot(CNNmodelHistory.history['accuracy'], label='train accuracy')
pyplot.plot(CNNmodelHistory.history['val_accuracy'], label='test accuracy')
pyplot.xlabel('No of Epochs')
pyplot.ylabel('Accuracy')
pyplot.legend()
pyplot.show()

# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Loss')
pyplot.plot(CNNmodelHistory.history['loss'], label='train loss')
pyplot.plot(CNNmodelHistory.history['val_loss'], label='test loss')
pyplot.xlabel('No of Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()

# %%
# evaluate the model
_, train_acc = CNNmodel.evaluate(X_train_sc, Y_train, verbose=0)
_, test_acc = CNNmodel.evaluate(X_val_sc, Y_val, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.989, Test: 0.898

# %%
plt.figure(figsize=(8,8))
      
cm = confusion_matrix_rnn(Y_val, CNNmodel.predict(X_val_sc))
plot_confusion_matrix(cm, classes=labels, normalize=False, title='confusion matrix', cmap = plt.cm.BuPu)
plt.show()

# %%
y_pred = CNNmodel.predict_classes(X_val_sc)

y_test =Y_val.argmax(axis=-1)
print(classification_report(y_test, y_pred, target_names=['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']))
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.98      0.92      0.95       496
#      Jogging       0.97      0.88      0.93       471
#      Sitting       0.83      1.00      0.91       420
#     Standing       0.82      0.74      0.78       491
#     Upstairs       0.80      0.85      0.82       532
#      Walking       1.00      1.00      1.00       537
#
#     accuracy                           0.90      2947
#    macro avg       0.90      0.90      0.90      2947
# weighted avg       0.90      0.90      0.90      2947

# %%
from keras.regularizers import l2,l1
import keras
from keras.layers import BatchNormalization

# %%
CMMmodel2 = Sequential()
CMMmodel2.add(Conv1D(filters=32, kernel_size=3, activation='relu',kernel_initializer='he_uniform',
                 kernel_regularizer=l2(0.1),input_shape=(128,9)))
CMMmodel2.add(Conv1D(filters=16, kernel_size=3, activation='relu',kernel_regularizer=l2(0.06),kernel_initializer='he_uniform'))
CMMmodel2.add(Dropout(0.65))
CMMmodel2.add(MaxPooling1D(pool_size=2))
CMMmodel2.add(Flatten())
CMMmodel2.add(Dense(32, activation='relu'))
CMMmodel2.add(Dense(6, activation='softmax'))
CMMmodel2.summary()
# Out:
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_7 (Conv1D)            (None, 126, 32)           896
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 124, 16)           1552
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 124, 16)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 62, 16)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 992)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                31776
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 34,422
# Trainable params: 34,422
# Non-trainable params: 0
# _________________________________________________________________

# %%
import math
adam = keras.optimizers.Adam(lr=0.001)
rmsprop = keras.optimizers.RMSprop(lr=0.001)
def step_decay(epoch):
    return float(0.001 * math.pow(0.6, math.floor((1+epoch)/10)))
from keras.callbacks import LearningRateScheduler
lrate = LearningRateScheduler(step_decay)
callbacks_list = [lrate]

CMMmodel2.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
CMMmodel2History = CMMmodel2.fit(X_train_sc,Y_train, epochs=30, batch_size=16,validation_data=(X_val_sc, Y_val), verbose=1)
# Out:
# Train on 7352 samples, validate on 2947 samples
# Epoch 1/30
# 7352/7352 [==============================] - 3s 445us/step - loss: 4.2929 - accuracy: 0.7818 - val_loss: 1.5552 - val_accuracy: 0.8694
# Epoch 2/30
# 7352/7352 [==============================] - 3s 411us/step - loss: 0.7363 - accuracy: 0.9200 - val_loss: 0.6579 - val_accuracy: 0.8785
# Epoch 3/30
# 7352/7352 [==============================] - 3s 417us/step - loss: 0.3791 - accuracy: 0.9232 - val_loss: 0.5461 - val_accuracy: 0.8626
# Epoch 4/30
# 7352/7352 [==============================] - 3s 419us/step - loss: 0.3162 - accuracy: 0.9295 - val_loss: 0.5042 - val_accuracy: 0.8704
# Epoch 5/30
# 7352/7352 [==============================] - 3s 406us/step - loss: 0.2814 - accuracy: 0.9287 - val_loss: 0.4419 - val_accuracy: 0.8751
# Epoch 6/30
# 7352/7352 [==============================] - 3s 406us/step - loss: 0.2630 - accuracy: 0.9346 - val_loss: 0.4260 - val_accuracy: 0.8867
# Epoch 7/30
# 7352/7352 [==============================] - 3s 391us/step - loss: 0.2388 - accuracy: 0.9395 - val_loss: 0.4183 - val_accuracy: 0.8785
# Epoch 8/30
# 7352/7352 [==============================] - 3s 405us/step - loss: 0.2406 - accuracy: 0.9368 - val_loss: 0.4495 - val_accuracy: 0.8734
# Epoch 9/30
# 7352/7352 [==============================] - 3s 402us/step - loss: 0.2245 - accuracy: 0.9407 - val_loss: 0.3903 - val_accuracy: 0.8985
# Epoch 10/30
# 7352/7352 [==============================] - 3s 415us/step - loss: 0.2205 - accuracy: 0.9373 - val_loss: 0.4121 - val_accuracy: 0.8867
# Epoch 11/30
# 7352/7352 [==============================] - 3s 404us/step - loss: 0.2170 - accuracy: 0.9419 - val_loss: 0.4251 - val_accuracy: 0.8765
# Epoch 12/30
# 7352/7352 [==============================] - 3s 406us/step - loss: 0.2132 - accuracy: 0.9436 - val_loss: 0.4995 - val_accuracy: 0.8249
# Epoch 13/30
# 7352/7352 [==============================] - 3s 411us/step - loss: 0.2030 - accuracy: 0.9464 - val_loss: 0.3652 - val_accuracy: 0.8928
# Epoch 14/30
# 7352/7352 [==============================] - 3s 397us/step - loss: 0.1911 - accuracy: 0.9453 - val_loss: 0.3354 - val_accuracy: 0.9013
# Epoch 15/30
# 7352/7352 [==============================] - 3s 397us/step - loss: 0.1965 - accuracy: 0.9433 - val_loss: 0.4022 - val_accuracy: 0.8741
# Epoch 16/30
# 7352/7352 [==============================] - 3s 396us/step - loss: 0.1997 - accuracy: 0.9415 - val_loss: 0.3633 - val_accuracy: 0.8972
# Epoch 17/30
# 7352/7352 [==============================] - 3s 409us/step - loss: 0.1833 - accuracy: 0.9459 - val_loss: 0.3371 - val_accuracy: 0.8999
# Epoch 18/30
# 7352/7352 [==============================] - 3s 392us/step - loss: 0.1900 - accuracy: 0.9441 - val_loss: 0.3488 - val_accuracy: 0.8877
# Epoch 19/30
# 7352/7352 [==============================] - 3s 393us/step - loss: 0.1786 - accuracy: 0.9455 - val_loss: 0.3739 - val_accuracy: 0.8860
# Epoch 20/30
# 7352/7352 [==============================] - 3s 393us/step - loss: 0.1850 - accuracy: 0.9444 - val_loss: 0.3410 - val_accuracy: 0.9019
# Epoch 21/30
# 7352/7352 [==============================] - 3s 389us/step - loss: 0.1783 - accuracy: 0.9449 - val_loss: 0.3819 - val_accuracy: 0.8877
# Epoch 22/30
# 7352/7352 [==============================] - 3s 395us/step - loss: 0.1824 - accuracy: 0.9467 - val_loss: 0.3376 - val_accuracy: 0.8928
# Epoch 23/30
# 7352/7352 [==============================] - 3s 394us/step - loss: 0.1888 - accuracy: 0.9446 - val_loss: 0.3486 - val_accuracy: 0.8914
# Epoch 24/30
# 7352/7352 [==============================] - 3s 401us/step - loss: 0.1772 - accuracy: 0.9441 - val_loss: 0.3234 - val_accuracy: 0.8931
# Epoch 25/30
# 7352/7352 [==============================] - 3s 394us/step - loss: 0.1822 - accuracy: 0.9433 - val_loss: 0.3575 - val_accuracy: 0.8924
# Epoch 26/30
# 7352/7352 [==============================] - 3s 400us/step - loss: 0.1717 - accuracy: 0.9490 - val_loss: 0.3440 - val_accuracy: 0.8958
# Epoch 27/30
# 7352/7352 [==============================] - 3s 396us/step - loss: 0.1726 - accuracy: 0.9479 - val_loss: 0.3444 - val_accuracy: 0.8867
# Epoch 28/30
# 7352/7352 [==============================] - 3s 399us/step - loss: 0.1740 - accuracy: 0.9457 - val_loss: 0.4069 - val_accuracy: 0.8816
# Epoch 29/30
# 7352/7352 [==============================] - 3s 393us/step - loss: 0.1679 - accuracy: 0.9479 - val_loss: 0.4290 - val_accuracy: 0.8894
# Epoch 30/30
# 7352/7352 [==============================] - 3s 392us/step - loss: 0.1769 - accuracy: 0.9457 - val_loss: 0.4180 - val_accuracy: 0.8680

# %%
# plot accuracy during training
pyplot.subplot(211)
pyplot.title('Accuracy')
pyplot.plot(CMMmodel2History.history['accuracy'], label='train accuracy')
pyplot.plot(CMMmodel2History.history['val_accuracy'], label='test accuracy')
pyplot.xlabel('No of Epochs')
pyplot.ylabel('Accuracy')
pyplot.legend()
pyplot.show()

# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Loss')
pyplot.plot(CMMmodel2History.history['loss'], label='train loss')
pyplot.plot(CMMmodel2History.history['val_loss'], label='test loss')
pyplot.xlabel('No of Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()

# %%
plt.figure(figsize=(8,8))
      
cm = confusion_matrix_rnn(Y_val, CMMmodel2.predict(X_val_sc))
plot_confusion_matrix(cm, classes=labels, normalize=False, title='confusion matrix', cmap = plt.cm.BuPu)
plt.show()

# %%
y_pred = CMMmodel2.predict_classes(X_val_sc)

y_test =Y_val.argmax(axis=-1)
print(classification_report(y_test, y_pred, target_names=['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']))
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.99      0.76      0.86       496
#      Jogging       0.86      0.93      0.90       471
#      Sitting       0.77      1.00      0.87       420
#     Standing       0.80      0.79      0.79       491
#     Upstairs       0.82      0.80      0.81       532
#      Walking       1.00      0.95      0.97       537
#
#     accuracy                           0.87      2947
#    macro avg       0.87      0.87      0.87      2947
# weighted avg       0.88      0.87      0.87      2947

# %%
X_train, Y_train, X_val, Y_val = data_scaled()
trials = Trials()
best_run, best_model, space = optim.minimize(model=model_cnn,
                                      data=data_scaled,
                                      algo=tpe.suggest,
                                      max_evals=100,
                                      trials=trials,notebook_name = 'Human Activity Detection-Without Verbose ',
                                      return_space = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-8844d1ff2dcc> in <module>()
#       1 X_train, Y_train, X_val, Y_val = data_scaled()
#       2 trials = Trials()
# ----> 3 best_run, best_model, space = optim.minimize(model=model_cnn,
#       4                                       data=data_scaled,
#       5                                       algo=tpe.suggest,
#
# NameError: name 'optim' is not defined

# %% [markdown]
# #  3. **`PSO OPTIMIZED CNN `**

# %%
import time
import numpy as np
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras import optimizers
import tensorflow as tf
from keras.models import Sequential 
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation, Dropout
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Activation, Dropout
from keras.utils import to_categorical

# %% [markdown]
# **PSO WITH MAIN.py file**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d419dbdb-9093-483e-a5b4-816a177905cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d419dbdb-9093-483e-a5b4-816a177905cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving utils.py to utils.py

# %%
import keras
#from psoCNN import psoCNN
import numpy as np
import time
import keras.backend
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
 
import os
import matplotlib
import matplotlib.pyplot as plt
#import tensorflow_hub as hub
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ### Population - Search Space

# %%
########################## POPULATION FILE ###################################################
#from particle import Particle

class Population:
    def __init__(self, pop_size, min_layer, max_layer, input_width, input_channels, conv_prob, pool_prob, fc_prob, max_conv_kernel, max_out_ch, max_fc_neurons, output_dim):
        # Compute maximum number of pooling layers for any given particle
        print('*************** population file **************************')
        max_pool_layers = 0
        in_w = input_width

        while in_w > 4:
            max_pool_layers += 1
            in_w = in_w/2

        self.particle = []
        for i in range(pop_size):
            self.particle.append(Particle(min_layer, max_layer, max_pool_layers, input_width, input_channels, conv_prob, pool_prob, fc_prob, max_conv_kernel, max_out_ch, max_fc_neurons, output_dim))

# %% [markdown]
# ## Particle - Each CNN architecture

# %%
import numpy as np
from copy import deepcopy
######################### PARTICLE FILE ########################################
import utils

import keras.backend
from keras.models import Model, Sequential
from keras.layers import Input, Add, Dense, Dropout, Flatten
from keras.layers import Activation, Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Activation, Conv1D, MaxPooling1D, AveragePooling1D
from keras.layers.advanced_activations import LeakyReLU
from keras import regularizers 
from keras.optimizers import Adam, Nadam
from keras.preprocessing.image import ImageDataGenerator

from keras.layers.normalization import BatchNormalization

import os
import tensorflow as tf

# Hide Tensorflow INFOS and WARNINGS
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

class Particle:
    def __init__(self, min_layer, max_layer, max_pool_layers, input_width, input_channels, \
        conv_prob, pool_prob, fc_prob, max_conv_kernel, max_out_ch, max_fc_neurons, output_dim):
        self.input_width = input_width
        #self.input_height = input_height
        self.input_channels = input_channels
        print('*************** particle file after edit**************************')


        self.num_pool_layers = 0
        self.max_pool_layers = max_pool_layers

        self.feature_width = input_width
        #self.feature_height = input_height

        self.depth = np.random.randint(min_layer, max_layer)
        self.conv_prob = conv_prob
        self.pool_prob = pool_prob
        self.fc_prob = fc_prob
        self.max_conv_kernel = max_conv_kernel
        self.max_out_ch = max_out_ch
        
        self.max_fc_neurons = max_fc_neurons
        self.output_dim = output_dim

        self.layers = []
        self.acc = None
        self.vel = [] # Initial velocity
        self.pBest = []

        # Build particle architecture
        self.initialization()
        
        # Update initial velocity
        for i in range(len(self.layers)):
            if self.layers[i]["type"] != "fc":
                self.vel.append({"type": "keep"})
            else:
                self.vel.append({"type": "keep_fc"})
        
        self.model = None
        self.pBest = deepcopy(self)

    
    def __str__(self):
        string = ""
        for z in range(len(self.layers)):
            string = string + self.layers[z]["type"] + " | "
        
        return string

    def initialization(self):
        out_channel = np.random.randint(3, self.max_out_ch)
        conv_kernel = np.random.randint(3, self.max_conv_kernel)
        
        # First layer is always a convolution layer
        self.layers.append({"type": "conv", "ou_c": out_channel, "kernel": conv_kernel})

        conv_prob = self.conv_prob
        pool_prob = conv_prob + self.pool_prob
        fc_prob = pool_prob

        for i in range(1, self.depth):
            if self.layers[-1]["type"] == "fc":
                layer_type = 1.1
            else:
                layer_type = np.random.rand()

            if layer_type < conv_prob:
                self.layers = utils.add_conv(self.layers, self.max_out_ch, self.max_conv_kernel)

            elif layer_type >= conv_prob and layer_type <= pool_prob:
                self.layers, self.num_pool_layers = utils.add_pool(self.layers, self.fc_prob, self.num_pool_layers, self.max_pool_layers, self.max_out_ch, self.max_conv_kernel, self.max_fc_neurons, self.output_dim)
            
            elif layer_type >= fc_prob:
                self.layers = utils.add_fc(self.layers, self.max_fc_neurons)
            
        self.layers[-1] = {"type": "fc", "ou_c": self.output_dim, "kernel": -1}
    

    def velocity(self, gBest, Cg):
        self.vel = utils.computeVelocity(gBest, self.pBest.layers, self.layers, Cg)

    def update(self):
        new_p = utils.updateParticle(self.layers, self.vel)
        new_p = self.validate(new_p)
        
        self.layers = new_p
        self.model = None

    def validate(self, list_layers):
        # Last layer should always be a fc with number of neurons equal to the number of outputs
        list_layers[-1] = {"type": "fc", "ou_c": self.output_dim, "kernel": -1}

        # Remove excess of Pooling layers
        self.num_pool_layers = 0
        for i in range(len(list_layers)):
            if list_layers[i]["type"] == "max_pool" or list_layers[i]["type"] == "avg_pool":
                self.num_pool_layers += 1
            
                if self.num_pool_layers >= self.max_pool_layers:
                    list_layers[i]["type"] = "remove"


        # Now, fix the inputs of each conv and pool layers
        updated_list_layers = []
        
        for i in range(0, len(list_layers)):
            if list_layers[i]["type"] != "remove":
                if list_layers[i]["type"] == "conv":
                    updated_list_layers.append({"type": "conv", "ou_c": list_layers[i]["ou_c"], "kernel": list_layers[i]["kernel"]})
                
                if list_layers[i]["type"] == "fc":
                    updated_list_layers.append(list_layers[i])

                if list_layers[i]["type"] == "max_pool":
                    updated_list_layers.append({"type": "max_pool", "ou_c": -1, "kernel": 2})

                if list_layers[i]["type"] == "avg_pool":
                    updated_list_layers.append({"type": "avg_pool", "ou_c": -1, "kernel": 2})

        return updated_list_layers

    ##### Model methods ####
    def model_compile(self, dropout_rate):
        list_layers = self.layers
        self.model = Sequential()

        for i in range(len(list_layers)):
            if list_layers[i]["type"] == "conv":
                n_out_filters = list_layers[i]["ou_c"]
                kernel_size = list_layers[i]["kernel"]

                if i == 0:
                    in_w = self.input_width
                    #in_h = self.input_height
                    in_c = self.input_channels
                    self.model.add(Conv1D(n_out_filters, kernel_size,padding="same" ,data_format="channels_last", kernel_initializer='he_normal', bias_initializer='he_normal', activation=None, input_shape=(in_w, in_c)))
                    self.model.add(BatchNormalization())
                    self.model.add(Activation("relu"))
                else:
                    self.model.add(Dropout(dropout_rate))
                    self.model.add(Conv1D(n_out_filters, kernel_size,padding="same", kernel_initializer='he_normal', bias_initializer='he_normal', activation=None))
                    self.model.add(BatchNormalization())
                    self.model.add(Activation("relu"))

            if list_layers[i]["type"] == "max_pool":
                kernel_size = list_layers[i]["kernel"]

                self.model.add(MaxPooling1D(pool_size=3, strides=2))

            if list_layers[i]["type"] == "avg_pool":
                kernel_size = list_layers[i]["kernel"]

                self.model.add(AveragePooling1D(pool_size=3, strides=2))
            
            if list_layers[i]["type"] == "fc":
                if list_layers[i-1]["type"] != "fc":
                    self.model.add(Flatten())

                self.model.add(Dropout(dropout_rate))

                if i == len(list_layers) - 1:
                    self.model.add(Dense(list_layers[i]["ou_c"], kernel_initializer='he_normal', bias_initializer='he_normal', activation=None))
                    self.model.add(BatchNormalization())
                    self.model.add(Activation("softmax"))
                else:
                    self.model.add(Dense(list_layers[i]["ou_c"], kernel_initializer='he_normal', bias_initializer='he_normal', kernel_regularizer=regularizers.l2(0.01), activation=None))
                    self.model.add(BatchNormalization())
                    self.model.add(Activation("relu"))

        adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, decay=0.0)

        self.model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=["accuracy"])
    

    def model_fit(self, x_train, y_train, batch_size, epochs):
        # TODO: add option to only use a sample size of the dataset

        hist = self.model.fit(x=x_train, y=y_train, validation_split=0.0, batch_size=batch_size, epochs=epochs)

        return hist

    def model_fit_complete(self, x_train, y_train, batch_size, epochs):
        hist = self.model.fit(x=x_train, y=y_train, validation_split=0.0, batch_size=batch_size, epochs=epochs)

        return hist
    
    def model_delete(self):
        # This is used to free up memory during PSO training
        del self.model
        keras.backend.clear_session()
        self.model = None

# %% [markdown]
# ## PSO-CNN for the dataset

# %%
import keras
from keras.datasets import mnist
from keras.datasets import fashion_mnist
from keras.datasets import cifar10
import keras.backend
from sklearn.metrics import classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support


#from population import Population

import numpy as np

from copy import deepcopy

class psoCNN:
    def __init__(self, dataset, n_iter, pop_size, batch_size, epochs, min_layer, max_layer, \
        conv_prob, pool_prob, fc_prob, max_conv_kernel, max_out_ch, max_fc_neurons, dropout_rate):
        
        self.pop_size = pop_size
        self.n_iter = n_iter
        self.epochs = epochs

        self.batch_size = batch_size
        self.gBest_acc = np.zeros(n_iter)
        self.gBest_test_acc = np.zeros(n_iter)
        
        if dataset == "HAR":
            print('coming to HAR *********************')
            input_width = 128
            input_height = 28
            input_channels = 9
            output_dim = 6
            self.x_train = X_train
            self.x_test = X_val
            print(self.x_train.shape)
            print(self.x_test.shape)

            
        self.y_train = Y_train
        self.y_test = Y_val
        print(self.y_train.shape)
        print(self.y_test.shape)


        print("Initializing population...")
        self.population = Population(pop_size, min_layer, max_layer, input_width, input_channels, conv_prob, pool_prob, fc_prob, max_conv_kernel, max_out_ch, max_fc_neurons, output_dim)
        #X_train.shape,Y_train.shape, X_val.shape, Y_val.shape
        print("Verifying accuracy of the current gBest...")
        print(self.population.particle[0])
        self.gBest = deepcopy(self.population.particle[0])
        self.gBest.model_compile(dropout_rate)
        print(self.x_train.shape)
        print(self.y_train.shape)
        print(self.x_test.shape)
        print(self.y_test.shape)
        hist = self.gBest.model_fit(self.x_train, self.y_train, batch_size=batch_size, epochs=epochs)
        test_metrics = self.gBest.model.evaluate(x=self.x_test, y=self.y_test, batch_size=batch_size)
        self.gBest.model_delete()


        history_dict = hist.history
        print(history_dict.keys())
        print('************* coming to dict keys *************')
        self.gBest_acc[0] = hist.history['accuracy'][-1]
        history_dict = hist.history
        print(history_dict.keys())
        self.gBest_test_acc[0] = test_metrics[1]
        
        self.population.particle[0].acc = hist.history['accuracy'][-1]
        self.population.particle[0].pBest.acc = hist.history['accuracy'][-1]

        print("Current gBest acc: " + str(self.gBest_acc[0]) + "\n")
        print("Current gBest test acc: " + str(self.gBest_test_acc[0]) + "\n")

        print("Looking for a new gBest in the population...")
        for i in range(1, self.pop_size):
            print('Initialization - Particle: ' + str(i+1))
            print(self.population.particle[i])

            self.population.particle[i].model_compile(dropout_rate)
            hist = self.population.particle[i].model_fit(self.x_train, self.y_train, batch_size=batch_size, epochs=epochs)
           
            self.population.particle[i].acc = hist.history['accuracy'][-1]
            self.population.particle[i].pBest.acc = hist.history['accuracy'][-1]

            if self.population.particle[i].pBest.acc >= self.gBest_acc[0]:
                print("Found a new gBest.")
                self.gBest = deepcopy(self.population.particle[i])
                self.gBest_acc[0] = self.population.particle[i].pBest.acc
                print("New gBest acc: " + str(self.gBest_acc[0]))

                test_metrics = self.gBest.model.evaluate(x=self.x_test, y=self.y_test, batch_size=batch_size)
                self.gBest_test_acc[0] = test_metrics[1]
                print("New gBest test acc: " + str(self.gBest_acc[0]))
            
            self.population.particle[i].model_delete()
            self.gBest.model_delete()


    def fit(self, Cg, dropout_rate):
        for i in range(1, self.n_iter):            
            gBest_acc = self.gBest_acc[i-1]
            gBest_test_acc = self.gBest_test_acc[i-1]

            for j in range(self.pop_size):
                print('Iteration: ' + str(i) + ' - Particle: ' + str(j+1))

                # Update particle velocity
                self.population.particle[j].velocity(self.gBest.layers, Cg)

                # Update particle architecture
                self.population.particle[j].update()

                print('Particle NEW architecture: ')
                print(self.population.particle[j])

                # Compute the acc in the updated particle
                self.population.particle[j].model_compile(dropout_rate)
                hist = self.population.particle[j].model_fit(self.x_train, self.y_train, batch_size=self.batch_size, epochs=self.epochs)
                self.population.particle[j].model_delete()

                self.population.particle[j].acc = hist.history['accuracy'][-1]
            
                f_test = self.population.particle[j].acc
                pBest_acc = self.population.particle[j].pBest.acc

                if f_test >= pBest_acc:
                    print("Found a new pBest.")
                    print("Current acc: " + str(f_test))
                    print("Past pBest acc: " + str(pBest_acc))
                    pBest_acc = f_test
                    self.population.particle[j].pBest = deepcopy(self.population.particle[j])

                    if pBest_acc >= gBest_acc:
                        print("Found a new gBest.")
                        gBest_acc = pBest_acc
                        self.gBest = deepcopy(self.population.particle[j])
                        self.gBest.model_compile(dropout_rate)
                        hist = self.gBest.model_fit(self.x_train, self.y_train, batch_size=self.batch_size, epochs=self.epochs)
                        test_metrics = self.gBest.model.evaluate(x=self.x_test, y=self.y_test, batch_size=self.batch_size)
                        self.gBest.model_delete()
                        gBest_test_acc = test_metrics[1]

                
            self.gBest_acc[i] = gBest_acc
            self.gBest_test_acc[i] = gBest_test_acc

            print("Current gBest acc: " + str(self.gBest_acc[i]))
            print("Current gBest test acc: " + str(self.gBest_test_acc[i]))

    def fit_gBest(self, batch_size, epochs, dropout_rate):
        print("\nFurther training gBest model...")
        self.gBest.model_compile(dropout_rate)        
        trainable_count = int(np.sum([keras.backend.count_params(p) for p in set(self.gBest.model.trainable_weights)]))
        print("gBest's number of trainable parameters: " + str(trainable_count))
        self.gBest.model_fit_complete(self.x_train, self.y_train, batch_size=batch_size, epochs=epochs)

        return trainable_count
    
    def evaluate_gBest(self, batch_size):
        print("\nEvaluating gBest model on the test set...")
        
        metrics = self.gBest.model.evaluate(x=self.x_test, y=self.y_test, batch_size=batch_size)
        plt.figure(figsize=(8,8))
        #print(confusion_matrix_rnn(Y_val, LSTMmodel.predict(X_val)))
        cm = confusion_matrix_rnn(self.y_test, self.gBest.model.predict(self.x_test))
        plot_confusion_matrix(cm, classes=labels, normalize=False, title='Normalized confusion matrix', cmap = plt.cm.BuPu)
        plt.show()
        _,val_acc = self.gBest.model.evaluate(self.x_test, self.y_test, verbose=0)
        _,train_acc = self.gBest.model.evaluate(self.x_test, self.y_test, verbose=0)

        y_pred = self.gBest.model.predict_classes(self.x_test)

        y_test =self.y_test.argmax(axis=-1)
        print(classification_report(y_test, y_pred, target_names=['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']))

        print('Train_accuracy',val_acc)
        print('validation accuracy',val_acc)
        print("\ngBest model loss in the test set: " + str(metrics[0]) + " - Test set accuracy: " + str(metrics[1]))
        return metrics

# %% [markdown]
# ## MAIN FUNCTION TO CALL PSO_CNN

# %%
if __name__ == '__main__':
    ######## Algorithm parameters ##################
    

    dataset = "HAR"
 
    
    number_runs = 1
    number_iterations = 5
    population_size = 20
    batch_size_pso = 32
    batch_size_full_training = 32
    
    epochs_pso = 1
    epochs_full_training = 100
    
    max_conv_output_channels = 256
    max_fully_connected_neurons = 300
    min_layer = 4
    max_layer = 20

    # Probability of each layer type (should sum to 1)
    probability_convolution = 0.6
    probability_pooling = 0.3
    probability_fully_connected = 0.1
    max_conv_kernel_size = 7
    Cg = 0.5
    dropout = 0.5

    ########### Run the algorithm ######################
    results_path = "./results/" + dataset + "/"
    if not os.path.exists(results_path):
            os.makedirs(results_path)
    all_gBest_metrics = np.zeros((number_runs, 2))
    runs_time = []
    all_gbest_par = []
    best_gBest_acc = 0
    for i in range(number_runs):
        print("Run number: " + str(i))
        start_time = time.time()
        pso = psoCNN(dataset=dataset, n_iter=number_iterations, pop_size=population_size,
                     batch_size=batch_size_pso, epochs=epochs_pso, min_layer=min_layer, max_layer=max_layer,
                     conv_prob=probability_convolution, pool_prob=probability_pooling,
                     fc_prob=probability_fully_connected, max_conv_kernel=max_conv_kernel_size,
                     max_out_ch=max_conv_output_channels, max_fc_neurons=max_fully_connected_neurons,
                     dropout_rate=dropout)
        pso.fit(Cg=Cg, dropout_rate=dropout)
        print(pso.gBest_acc)

        # Plot current gBest
        matplotlib.use('Agg')
        plt.plot(pso.gBest_acc)
        plt.xlabel("Iteration")
        plt.ylabel("gBest acc")
        plt.savefig(results_path + "gBest-iter-" + str(i) + ".png")
        plt.close()
        print('gBest architecture: ')
        print(pso.gBest)
    
        np.save(results_path + "gBest_inter_" + str(i) + "_acc_history.npy", pso.gBest_acc)
        np.save(results_path + "gBest_iter_" + str(i) + "_test_acc_history.npy", pso.gBest_test_acc)
        end_time = time.time()
        running_time = end_time - start_time
        runs_time.append(running_time)

        # Fully train the gBest model found
        n_parameters = pso.fit_gBest(batch_size=batch_size_full_training, epochs=epochs_full_training, dropout_rate=dropout)
        all_gbest_par.append(n_parameters)

        # Evaluate the fully trained gBest model
        gBest_metrics = pso.evaluate_gBest(batch_size=batch_size_full_training)
        if gBest_metrics[1] >= best_gBest_acc:
            best_gBest_acc = gBest_metrics[1]

            # Save best gBest model
            best_gBest_yaml = pso.gBest.model.to_yaml()
            with open(results_path + "best-gBest-model.yaml", "w") as yaml_file:
                yaml_file.write(best_gBest_yaml)
            
            # Save best gBest model weights to HDF5 file
            pso.gBest.model.save_weights(results_path + "best-gBest-weights.h5")
        all_gBest_metrics[i, 0] = gBest_metrics[0]
        all_gBest_metrics[i, 1] = gBest_metrics[1]
        print("This run took: " + str(running_time) + " seconds.")
         # Compute mean accuracy of all runs
        all_gBest_mean_metrics = np.mean(all_gBest_metrics, axis=0)
        np.save(results_path + "/time_to_run.npy", runs_time)

        # Save all gBest metrics
        np.save(results_path + "/all_gBest_metrics.npy", all_gBest_metrics)

        # Save results in a text file
        output_str = "All gBest number of parameters: " + str(all_gbest_par) + "\n"
        output_str = output_str + "All gBest test accuracies: " + str(all_gBest_metrics[:,1]) + "\n"
        output_str = output_str + "All running times: " + str(runs_time) + "\n"
        output_str = output_str + "Mean loss of all runs: " + str(all_gBest_mean_metrics[0]) + "\n"
        output_str = output_str + "Mean accuracy of all runs: " + str(all_gBest_mean_metrics[1]) + "\n"
        print(output_str)
        with open(results_path + "/final_results.txt", "w") as f:
            try:
                print(output_str, file=f)
            except SyntaxError:
                print >> f, output_str
# Out:
# Run number: 0
# coming to HAR *********************
# (7352, 128, 9)
# (2947, 128, 9)
# (7352, 6)
# (2947, 6)
# Initializing population...
# *************** population file **************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# *************** particle file after edit**************************
# Verifying accuracy of the current gBest...
# conv | max_pool | conv | max_pool | conv | fc |
# (7352, 128, 9)
# (7352, 6)
# (2947, 128, 9)
# (2947, 6)
# Epoch 1/1
# 7352/7352 [==============================] - 12s 2ms/step - loss: 0.7384 - accuracy: 0.7901
# 2947/2947 [==============================] - 1s 472us/step
# dict_keys(['loss', 'accuracy'])
# ************* coming to dict keys *************
# dict_keys(['loss', 'accuracy'])
# Current gBest acc: 0.7901251316070557
#
# Current gBest test acc: 0.9097387194633484
#
# Looking for a new gBest in the population...
# Initialization - Particle: 2
# conv | avg_pool | conv | conv | conv | conv | avg_pool | conv | avg_pool | avg_pool | conv | conv | fc |
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Epoch 1/1
# 7352/7352 [==============================] - 25s 3ms/step - loss: 1.3175 - accuracy: 0.4648
# Initialization - Particle: 3
# conv | conv | avg_pool | fc | fc | fc | fc | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 17s 2ms/step - loss: 25.6102 - accuracy: 0.2412
# Initialization - Particle: 4
# conv | conv | max_pool | conv | conv | conv | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 49s 7ms/step - loss: 0.8784 - accuracy: 0.6768
# Initialization - Particle: 5
# conv | conv | conv | conv | conv | conv | avg_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 60s 8ms/step - loss: 2.7694 - accuracy: 0.7172
# Initialization - Particle: 6
# conv | avg_pool | conv | max_pool | avg_pool | conv | conv | conv | max_pool | conv | conv | max_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 20s 3ms/step - loss: 1.0952 - accuracy: 0.5505
# Initialization - Particle: 7
# conv | fc | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 8s 1ms/step - loss: 18.4044 - accuracy: 0.3086
# Initialization - Particle: 8
# conv | fc | fc | fc | fc | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 7s 905us/step - loss: 26.1511 - accuracy: 0.2429
# Initialization - Particle: 9
# conv | conv | conv | avg_pool | conv | conv | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 34s 5ms/step - loss: 11.0524 - accuracy: 0.2639
# Initialization - Particle: 10
# conv | conv | fc | fc | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 34s 5ms/step - loss: 15.1295 - accuracy: 0.2319
# Initialization - Particle: 11
# conv | avg_pool | conv | conv | conv | conv | conv | max_pool | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 42s 6ms/step - loss: 16.7709 - accuracy: 0.2312
# Initialization - Particle: 12
# conv | conv | max_pool | conv | conv | conv | avg_pool | conv | conv | conv | conv | avg_pool | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 23s 3ms/step - loss: 2.7672 - accuracy: 0.4129
# Initialization - Particle: 13
# conv | max_pool | conv | conv | max_pool | avg_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 0.9093 - accuracy: 0.6859
# Initialization - Particle: 14
# conv | conv | max_pool | avg_pool | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 14s 2ms/step - loss: 4.1116 - accuracy: 0.7097
# Initialization - Particle: 15
# conv | conv | conv | conv | conv | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 119s 16ms/step - loss: 0.8228 - accuracy: 0.7278
# Initialization - Particle: 16
# conv | avg_pool | conv | conv | max_pool | avg_pool | fc | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 19s 3ms/step - loss: 11.5589 - accuracy: 0.2301
# Initialization - Particle: 17
# conv | conv | fc | fc | fc | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 34s 5ms/step - loss: 19.5938 - accuracy: 0.2353
# Initialization - Particle: 18
# conv | conv | conv | conv | conv | avg_pool | conv | avg_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 34s 5ms/step - loss: 0.9009 - accuracy: 0.6734
# Initialization - Particle: 19
# conv | max_pool | conv | max_pool | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 10s 1ms/step - loss: 12.4008 - accuracy: 0.3032
# Initialization - Particle: 20
# conv | conv | avg_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 8s 1ms/step - loss: 0.8212 - accuracy: 0.7489
# Iteration: 1 - Particle: 1
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 13s 2ms/step - loss: 0.7821 - accuracy: 0.7554
# Iteration: 1 - Particle: 2
# Particle NEW architecture:
# conv | max_pool | conv | conv | conv | conv | avg_pool | avg_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 21s 3ms/step - loss: 0.9917 - accuracy: 0.6438
# Found a new pBest.
# Current acc: 0.6437704
# Past pBest acc: 0.46477148
# Iteration: 1 - Particle: 3
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 16s 2ms/step - loss: 7.5062 - accuracy: 0.5192
# Found a new pBest.
# Current acc: 0.51917845
# Past pBest acc: 0.24115887
# Iteration: 1 - Particle: 4
# Particle NEW architecture:
# conv | max_pool | max_pool | max_pool | conv | conv | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 18s 2ms/step - loss: 0.8773 - accuracy: 0.7169
# Found a new pBest.
# Current acc: 0.7169478
# Past pBest acc: 0.67682266
# Iteration: 1 - Particle: 5
# Particle NEW architecture:
# conv | max_pool | conv | conv | conv | conv | avg_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 32s 4ms/step - loss: 0.9267 - accuracy: 0.6723
# Iteration: 1 - Particle: 6
# Particle NEW architecture:
# conv | avg_pool | conv | max_pool | conv | conv | conv | max_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 19s 3ms/step - loss: 0.9174 - accuracy: 0.6712
# Found a new pBest.
# Current acc: 0.67124593
# Past pBest acc: 0.5504625
# Iteration: 1 - Particle: 7
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | conv | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 16s 2ms/step - loss: 14.7818 - accuracy: 0.3158
# Found a new pBest.
# Current acc: 0.31583244
# Past pBest acc: 0.3086235
# Iteration: 1 - Particle: 8
# Particle NEW architecture:
# conv | conv | max_pool | fc | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 10s 1ms/step - loss: 12.1154 - accuracy: 0.2380
# Iteration: 1 - Particle: 9
# Particle NEW architecture:
# conv | conv | conv | max_pool | conv | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 40s 5ms/step - loss: 6.0779 - accuracy: 0.4992
# Found a new pBest.
# Current acc: 0.4991839
# Past pBest acc: 0.2638738
# Iteration: 1 - Particle: 10
# Particle NEW architecture:
# conv | conv | max_pool | conv | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 48s 6ms/step - loss: 5.9139 - accuracy: 0.3278
# Found a new pBest.
# Current acc: 0.32780197
# Past pBest acc: 0.23190968
# Iteration: 1 - Particle: 11
# Particle NEW architecture:
# conv | avg_pool | conv | conv | conv | conv | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 33s 5ms/step - loss: 6.7107 - accuracy: 0.3138
# Found a new pBest.
# Current acc: 0.31379217
# Past pBest acc: 0.2312296
# Iteration: 1 - Particle: 12
# Particle NEW architecture:
# conv | conv | conv | max_pool | conv | conv | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 21s 3ms/step - loss: 1.1220 - accuracy: 0.5317
# Found a new pBest.
# Current acc: 0.531692
# Past pBest acc: 0.41294885
# Iteration: 1 - Particle: 13
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | max_pool | avg_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 5s 718us/step - loss: 0.9523 - accuracy: 0.6835
# Iteration: 1 - Particle: 14
# Particle NEW architecture:
# conv | max_pool | max_pool | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 13s 2ms/step - loss: 1.5968 - accuracy: 0.7896
# Found a new pBest.
# Current acc: 0.78958106
# Past pBest acc: 0.70973885
# Iteration: 1 - Particle: 15
# Particle NEW architecture:
# conv | max_pool | conv | conv | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 55s 7ms/step - loss: 0.6833 - accuracy: 0.8127
# Found a new pBest.
# Current acc: 0.812704
# Past pBest acc: 0.72782916
# Found a new gBest.
# Epoch 1/1
# 7352/7352 [==============================] - 55s 7ms/step - loss: 0.7055 - accuracy: 0.7920
# 2947/2947 [==============================] - 4s 2ms/step
# Iteration: 1 - Particle: 16
# Particle NEW architecture:
# conv | avg_pool | conv | conv | max_pool | avg_pool | fc | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 19s 3ms/step - loss: 6.4439 - accuracy: 0.2399
# Found a new pBest.
# Current acc: 0.23993471
# Past pBest acc: 0.23014146
# Iteration: 1 - Particle: 17
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 32s 4ms/step - loss: 1.9672 - accuracy: 0.8470
# Found a new pBest.
# Current acc: 0.8469804
# Past pBest acc: 0.23531012
# Found a new gBest.
# Epoch 1/1
# 7352/7352 [==============================] - 32s 4ms/step - loss: 2.0738 - accuracy: 0.8392
# 2947/2947 [==============================] - 3s 916us/step
# Iteration: 1 - Particle: 18
# Particle NEW architecture:
# conv | conv | conv | conv | conv | avg_pool | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 35s 5ms/step - loss: 0.9024 - accuracy: 0.6933
# Found a new pBest.
# Current acc: 0.69328076
# Past pBest acc: 0.6734222
# Iteration: 1 - Particle: 19
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 10s 1ms/step - loss: 8.3343 - accuracy: 0.3878
# Found a new pBest.
# Current acc: 0.38778564
# Past pBest acc: 0.3031828
# Iteration: 1 - Particle: 20
# Particle NEW architecture:
# conv | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 35s 5ms/step - loss: 2.4370 - accuracy: 0.7937
# Found a new pBest.
# Current acc: 0.7936616
# Past pBest acc: 0.74891186
# Current gBest acc: 0.8469803929328918
# Current gBest test acc: 0.8859857320785522
# Iteration: 2 - Particle: 1
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.7028 - accuracy: 0.8074
# Found a new pBest.
# Current acc: 0.80739933
# Past pBest acc: 0.79012513
# Iteration: 2 - Particle: 2
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 15s 2ms/step - loss: 2.6082 - accuracy: 0.7039
# Found a new pBest.
# Current acc: 0.7038901
# Past pBest acc: 0.6437704
# Iteration: 2 - Particle: 3
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 6s 865us/step - loss: 4.3421 - accuracy: 0.5909
# Found a new pBest.
# Current acc: 0.59085965
# Past pBest acc: 0.51917845
# Iteration: 2 - Particle: 4
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 28s 4ms/step - loss: 0.8348 - accuracy: 0.7454
# Found a new pBest.
# Current acc: 0.7453754
# Past pBest acc: 0.7169478
# Iteration: 2 - Particle: 5
# Particle NEW architecture:
# conv | conv | conv | avg_pool | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 36s 5ms/step - loss: 1.8969 - accuracy: 0.8402
# Found a new pBest.
# Current acc: 0.84017956
# Past pBest acc: 0.7172198
# Iteration: 2 - Particle: 6
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 16s 2ms/step - loss: 2.3065 - accuracy: 0.7674
# Found a new pBest.
# Current acc: 0.7674102
# Past pBest acc: 0.67124593
# Iteration: 2 - Particle: 7
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 9.2858 - accuracy: 0.4600
# Found a new pBest.
# Current acc: 0.4600109
# Past pBest acc: 0.31583244
# Iteration: 2 - Particle: 8
# Particle NEW architecture:
# conv | conv | fc | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 31s 4ms/step - loss: 9.6493 - accuracy: 0.4562
# Found a new pBest.
# Current acc: 0.4562024
# Past pBest acc: 0.24292709
# Iteration: 2 - Particle: 9
# Particle NEW architecture:
# conv | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 27s 4ms/step - loss: 1.3761 - accuracy: 0.7106
# Found a new pBest.
# Current acc: 0.71055496
# Past pBest acc: 0.4991839
# Iteration: 2 - Particle: 10
# Particle NEW architecture:
# conv | conv | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 82s 11ms/step - loss: 1.4592 - accuracy: 0.6772
# Found a new pBest.
# Current acc: 0.67723066
# Past pBest acc: 0.32780197
# Iteration: 2 - Particle: 11
# Particle NEW architecture:
# conv | max_pool | conv | conv | conv | conv | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 37s 5ms/step - loss: 3.5801 - accuracy: 0.2831
# Iteration: 2 - Particle: 12
# Particle NEW architecture:
# conv | max_pool | conv | conv | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 17s 2ms/step - loss: 1.0942 - accuracy: 0.5955
# Found a new pBest.
# Current acc: 0.5954842
# Past pBest acc: 0.531692
# Iteration: 2 - Particle: 13
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 12s 2ms/step - loss: 2.2157 - accuracy: 0.7598
# Found a new pBest.
# Current acc: 0.7597933
# Past pBest acc: 0.6859358
# Iteration: 2 - Particle: 14
# Particle NEW architecture:
# conv | max_pool | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 18s 2ms/step - loss: 1.5516 - accuracy: 0.8084
# Found a new pBest.
# Current acc: 0.80835146
# Past pBest acc: 0.78958106
# Iteration: 2 - Particle: 15
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 32s 4ms/step - loss: 1.9405 - accuracy: 0.8508
# Found a new pBest.
# Current acc: 0.8507889
# Past pBest acc: 0.812704
# Found a new gBest.
# Epoch 1/1
# 7352/7352 [==============================] - 31s 4ms/step - loss: 2.0349 - accuracy: 0.8508
# 2947/2947 [==============================] - 3s 891us/step
# Iteration: 2 - Particle: 16
# Particle NEW architecture:
# conv | avg_pool | conv | avg_pool | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 8s 1ms/step - loss: 5.0870 - accuracy: 0.5023
# Found a new pBest.
# Current acc: 0.5023123
# Past pBest acc: 0.23993471
# Iteration: 2 - Particle: 17
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 34s 5ms/step - loss: 1.9439 - accuracy: 0.8492
# Found a new pBest.
# Current acc: 0.8491567
# Past pBest acc: 0.8469804
# Iteration: 2 - Particle: 18
# Particle NEW architecture:
# conv | max_pool | conv | conv | avg_pool | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 0.8604 - accuracy: 0.7191
# Found a new pBest.
# Current acc: 0.719124
# Past pBest acc: 0.69328076
# Iteration: 2 - Particle: 19
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 3.7854 - accuracy: 0.5990
# Found a new pBest.
# Current acc: 0.59902066
# Past pBest acc: 0.38778564
# Iteration: 2 - Particle: 20
# Particle NEW architecture:
# conv | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 35s 5ms/step - loss: 2.3809 - accuracy: 0.8060
# Found a new pBest.
# Current acc: 0.80603915
# Past pBest acc: 0.7936616
# Current gBest acc: 0.8507888913154602
# Current gBest test acc: 0.9012554883956909
# Iteration: 3 - Particle: 1
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 17s 2ms/step - loss: 0.7112 - accuracy: 0.7945
# Iteration: 3 - Particle: 2
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 15s 2ms/step - loss: 2.6015 - accuracy: 0.7076
# Found a new pBest.
# Current acc: 0.70756257
# Past pBest acc: 0.7038901
# Iteration: 3 - Particle: 3
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 7s 886us/step - loss: 4.3706 - accuracy: 0.6020
# Found a new pBest.
# Current acc: 0.60201305
# Past pBest acc: 0.59085965
# Iteration: 3 - Particle: 4
# Particle NEW architecture:
# conv | max_pool | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 26s 4ms/step - loss: 0.6316 - accuracy: 0.8483
# Found a new pBest.
# Current acc: 0.8483406
# Past pBest acc: 0.7453754
# Iteration: 3 - Particle: 5
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 32s 4ms/step - loss: 1.9991 - accuracy: 0.8451
# Found a new pBest.
# Current acc: 0.84507614
# Past pBest acc: 0.84017956
# Iteration: 3 - Particle: 6
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 22s 3ms/step - loss: 2.1161 - accuracy: 0.8077
# Found a new pBest.
# Current acc: 0.80767137
# Past pBest acc: 0.7674102
# Iteration: 3 - Particle: 7
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 12s 2ms/step - loss: 7.5522 - accuracy: 0.6017
# Found a new pBest.
# Current acc: 0.601741
# Past pBest acc: 0.4600109
# Iteration: 3 - Particle: 8
# Particle NEW architecture:
# conv | conv | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 31s 4ms/step - loss: 7.0105 - accuracy: 0.5275
# Found a new pBest.
# Current acc: 0.52747554
# Past pBest acc: 0.4562024
# Iteration: 3 - Particle: 9
# Particle NEW architecture:
# conv | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 27s 4ms/step - loss: 1.4115 - accuracy: 0.6990
# Iteration: 3 - Particle: 10
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 22s 3ms/step - loss: 1.3162 - accuracy: 0.7031
# Found a new pBest.
# Current acc: 0.703074
# Past pBest acc: 0.67723066
# Iteration: 3 - Particle: 11
# Particle NEW architecture:
# conv | max_pool | conv | conv | conv | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 26s 4ms/step - loss: 3.2435 - accuracy: 0.3184
# Found a new pBest.
# Current acc: 0.31841674
# Past pBest acc: 0.31379217
# Iteration: 3 - Particle: 12
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 23s 3ms/step - loss: 2.3344 - accuracy: 0.7953
# Found a new pBest.
# Current acc: 0.7952938
# Past pBest acc: 0.5954842
# Iteration: 3 - Particle: 13
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 10s 1ms/step - loss: 2.3562 - accuracy: 0.7674
# Found a new pBest.
# Current acc: 0.7674102
# Past pBest acc: 0.7597933
# Iteration: 3 - Particle: 14
# Particle NEW architecture:
# conv | max_pool | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 17s 2ms/step - loss: 1.5791 - accuracy: 0.8152
# Found a new pBest.
# Current acc: 0.81515235
# Past pBest acc: 0.80835146
# Iteration: 3 - Particle: 15
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 31s 4ms/step - loss: 1.9531 - accuracy: 0.8595
# Found a new pBest.
# Current acc: 0.85949403
# Past pBest acc: 0.8507889
# Found a new gBest.
# Epoch 1/1
# 7352/7352 [==============================] - 32s 4ms/step - loss: 2.0458 - accuracy: 0.8478
# 2947/2947 [==============================] - 3s 922us/step
# Iteration: 3 - Particle: 16
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 7s 941us/step - loss: 3.1391 - accuracy: 0.5449
# Found a new pBest.
# Current acc: 0.54488575
# Past pBest acc: 0.5023123
# Iteration: 3 - Particle: 17
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 33s 5ms/step - loss: 1.9144 - accuracy: 0.8521
# Found a new pBest.
# Current acc: 0.85214907
# Past pBest acc: 0.8491567
# Iteration: 3 - Particle: 18
# Particle NEW architecture:
# conv | max_pool | conv | conv | avg_pool | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 10s 1ms/step - loss: 2.4442 - accuracy: 0.7058
# Iteration: 3 - Particle: 19
# Particle NEW architecture:
# conv | max_pool | conv | max_pool | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 1.7120 - accuracy: 0.6536
# Found a new pBest.
# Current acc: 0.6535637
# Past pBest acc: 0.59902066
# Iteration: 3 - Particle: 20
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 22s 3ms/step - loss: 2.0685 - accuracy: 0.8335
# Found a new pBest.
# Current acc: 0.8335147
# Past pBest acc: 0.80603915
# Current gBest acc: 0.8594940304756165
# Current gBest test acc: 0.885646402835846
# Iteration: 4 - Particle: 1
# Particle NEW architecture:
# conv | max_pool | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 0.7597 - accuracy: 0.7758
# Iteration: 4 - Particle: 2
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 15s 2ms/step - loss: 2.5124 - accuracy: 0.7144
# Found a new pBest.
# Current acc: 0.71436346
# Past pBest acc: 0.70756257
# Iteration: 4 - Particle: 3
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 2.3432 - accuracy: 0.7719
# Found a new pBest.
# Current acc: 0.7718988
# Past pBest acc: 0.60201305
# Iteration: 4 - Particle: 4
# Particle NEW architecture:
# conv | max_pool | conv | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 26s 4ms/step - loss: 0.6526 - accuracy: 0.8417
# Iteration: 4 - Particle: 5
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 31s 4ms/step - loss: 1.9692 - accuracy: 0.8482
# Found a new pBest.
# Current acc: 0.84820455
# Past pBest acc: 0.84507614
# Iteration: 4 - Particle: 6
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 11s 2ms/step - loss: 2.3419 - accuracy: 0.7829
# Iteration: 4 - Particle: 7
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 14s 2ms/step - loss: 7.6717 - accuracy: 0.6118
# Found a new pBest.
# Current acc: 0.61180633
# Past pBest acc: 0.601741
# Iteration: 4 - Particle: 8
# Particle NEW architecture:
# conv | conv | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 12s 2ms/step - loss: 5.0980 - accuracy: 0.5592
# Found a new pBest.
# Current acc: 0.55916756
# Past pBest acc: 0.52747554
# Iteration: 4 - Particle: 9
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 12s 2ms/step - loss: 1.3583 - accuracy: 0.7144
# Found a new pBest.
# Current acc: 0.71436346
# Past pBest acc: 0.71055496
# Iteration: 4 - Particle: 10
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 22s 3ms/step - loss: 1.2858 - accuracy: 0.6941
# Iteration: 4 - Particle: 11
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 21s 3ms/step - loss: 2.9740 - accuracy: 0.3579
# Found a new pBest.
# Current acc: 0.35786182
# Past pBest acc: 0.31841674
# Iteration: 4 - Particle: 12
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 23s 3ms/step - loss: 2.1280 - accuracy: 0.8050
# Found a new pBest.
# Current acc: 0.804951
# Past pBest acc: 0.7952938
# Iteration: 4 - Particle: 13
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 11s 2ms/step - loss: 2.3434 - accuracy: 0.7607
# Iteration: 4 - Particle: 14
# Particle NEW architecture:
# conv | max_pool | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 17s 2ms/step - loss: 1.5940 - accuracy: 0.8028
# Iteration: 4 - Particle: 15
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 33s 5ms/step - loss: 2.0189 - accuracy: 0.8470
# Iteration: 4 - Particle: 16
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 1.7993 - accuracy: 0.7535
# Found a new pBest.
# Current acc: 0.75353646
# Past pBest acc: 0.54488575
# Iteration: 4 - Particle: 17
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 33s 5ms/step - loss: 1.9820 - accuracy: 0.8419
# Iteration: 4 - Particle: 18
# Particle NEW architecture:
# conv | max_pool | conv | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 11s 1ms/step - loss: 2.5623 - accuracy: 0.6923
# Iteration: 4 - Particle: 19
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 9s 1ms/step - loss: 1.6050 - accuracy: 0.6819
# Found a new pBest.
# Current acc: 0.68185526
# Past pBest acc: 0.6535637
# Iteration: 4 - Particle: 20
# Particle NEW architecture:
# conv | max_pool | conv | fc | fc |
# Epoch 1/1
# 7352/7352 [==============================] - 21s 3ms/step - loss: 2.0846 - accuracy: 0.8405
# Found a new pBest.
# Current acc: 0.8404516
# Past pBest acc: 0.8335147
# Current gBest acc: 0.8594940304756165
# Current gBest test acc: 0.885646402835846
# [0.79012513 0.84698039 0.85078889 0.85949403 0.85949403]
# gBest architecture:
# conv | max_pool | conv | fc | fc |
#
# Further training gBest model...
# gBest's number of trainable parameters: 2549719
# Epoch 1/100
# 7352/7352 [==============================] - 32s 4ms/step - loss: 2.0172 - accuracy: 0.8463
# Epoch 2/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.7839 - accuracy: 0.9268
# Epoch 3/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.6874 - accuracy: 0.9363
# Epoch 4/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.6419 - accuracy: 0.9358
# Epoch 5/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.6034 - accuracy: 0.9395
# Epoch 6/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5823 - accuracy: 0.9353
# Epoch 7/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5752 - accuracy: 0.9397
# Epoch 8/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5821 - accuracy: 0.9410
# Epoch 9/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5322 - accuracy: 0.9441
# Epoch 10/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5302 - accuracy: 0.9444
# Epoch 11/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5918 - accuracy: 0.9392
# Epoch 12/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5661 - accuracy: 0.9426
# Epoch 13/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5304 - accuracy: 0.9399
# Epoch 14/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5548 - accuracy: 0.9482
# Epoch 15/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5527 - accuracy: 0.9416
# Epoch 16/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4823 - accuracy: 0.9440
# Epoch 17/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5316 - accuracy: 0.9437
# Epoch 18/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4981 - accuracy: 0.9467
# Epoch 19/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4970 - accuracy: 0.9460
# Epoch 20/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5606 - accuracy: 0.9423
# Epoch 21/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5076 - accuracy: 0.9470
# Epoch 22/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5474 - accuracy: 0.9427
# Epoch 23/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5165 - accuracy: 0.9441
# Epoch 24/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4762 - accuracy: 0.9467
# Epoch 25/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5010 - accuracy: 0.9463
# Epoch 26/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5340 - accuracy: 0.9471
# Epoch 27/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5456 - accuracy: 0.9461
# Epoch 28/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5350 - accuracy: 0.9411
# Epoch 29/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5500 - accuracy: 0.9461
# Epoch 30/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5039 - accuracy: 0.9436
# Epoch 31/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4598 - accuracy: 0.9531
# Epoch 32/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5067 - accuracy: 0.9453
# Epoch 33/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4384 - accuracy: 0.9457
# Epoch 34/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5187 - accuracy: 0.9464
# Epoch 35/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4981 - accuracy: 0.9456
# Epoch 36/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4288 - accuracy: 0.9498
# Epoch 37/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4574 - accuracy: 0.9484
# Epoch 38/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4467 - accuracy: 0.9498
# Epoch 39/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4161 - accuracy: 0.9490
# Epoch 40/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4163 - accuracy: 0.9509
# Epoch 41/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5147 - accuracy: 0.9482
# Epoch 42/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5204 - accuracy: 0.9468
# Epoch 43/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5479 - accuracy: 0.9472
# Epoch 44/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4881 - accuracy: 0.9501
# Epoch 45/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.5285 - accuracy: 0.9479
# Epoch 46/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4202 - accuracy: 0.9486
# Epoch 47/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4580 - accuracy: 0.9472
# Epoch 48/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4441 - accuracy: 0.9460
# Epoch 49/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4910 - accuracy: 0.9491
# Epoch 50/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4565 - accuracy: 0.9484
# Epoch 51/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4135 - accuracy: 0.9478
# Epoch 52/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4191 - accuracy: 0.9505
# Epoch 53/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4135 - accuracy: 0.9508
# Epoch 54/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3925 - accuracy: 0.9510
# Epoch 55/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4655 - accuracy: 0.9491
# Epoch 56/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4362 - accuracy: 0.9529
# Epoch 57/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4130 - accuracy: 0.9504
# Epoch 58/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4739 - accuracy: 0.9542
# Epoch 59/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4752 - accuracy: 0.9497
# Epoch 60/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4367 - accuracy: 0.9520
# Epoch 61/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4372 - accuracy: 0.9536
# Epoch 62/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3935 - accuracy: 0.9510
# Epoch 63/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4606 - accuracy: 0.9487
# Epoch 64/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3972 - accuracy: 0.9509
# Epoch 65/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4528 - accuracy: 0.9506
# Epoch 66/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3968 - accuracy: 0.9536
# Epoch 67/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4300 - accuracy: 0.9506
# Epoch 68/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4104 - accuracy: 0.9518
# Epoch 69/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4338 - accuracy: 0.9529
# Epoch 70/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4014 - accuracy: 0.9542
# Epoch 71/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3830 - accuracy: 0.9502
# Epoch 72/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4275 - accuracy: 0.9521
# Epoch 73/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3784 - accuracy: 0.9554
# Epoch 74/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3660 - accuracy: 0.9536
# Epoch 75/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4313 - accuracy: 0.9509
# Epoch 76/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3565 - accuracy: 0.9531
# Epoch 77/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4281 - accuracy: 0.9529
# Epoch 78/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4588 - accuracy: 0.9525
# Epoch 79/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3989 - accuracy: 0.9509
# Epoch 80/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3719 - accuracy: 0.9532
# Epoch 81/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3872 - accuracy: 0.9543
# Epoch 82/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3526 - accuracy: 0.9527
# Epoch 83/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3532 - accuracy: 0.9540
# Epoch 84/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4255 - accuracy: 0.9521
# Epoch 85/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3945 - accuracy: 0.9521
# Epoch 86/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4031 - accuracy: 0.9520
# Epoch 87/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4193 - accuracy: 0.9529
# Epoch 88/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3894 - accuracy: 0.9532
# Epoch 89/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3963 - accuracy: 0.9551
# Epoch 90/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3714 - accuracy: 0.9523
# Epoch 91/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3494 - accuracy: 0.9566
# Epoch 92/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3752 - accuracy: 0.9553
# Epoch 93/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3840 - accuracy: 0.9543
# Epoch 94/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4157 - accuracy: 0.9542
# Epoch 95/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4013 - accuracy: 0.9572
# Epoch 96/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.3759 - accuracy: 0.9531
# Epoch 97/100
# 7352/7352 [==============================] - 31s 4ms/step - loss: 0.4000 - accuracy: 0.9506
# Epoch 98/100
# 7352/7352 [==============================] - 30s 4ms/step - loss: 0.3800 - accuracy: 0.9540
# Epoch 99/100
# 7352/7352 [==============================] - 29s 4ms/step - loss: 0.3838 - accuracy: 0.9518
# Epoch 100/100
# 7352/7352 [==============================] - 29s 4ms/step - loss: 0.3805 - accuracy: 0.9525
#
# Evaluating gBest model on the test set...
# 2947/2947 [==============================] - 2s 823us/step
#               precision    recall  f1-score   support
#
#   Downstairs       0.98      1.00      0.99       496
#      Jogging       0.99      0.95      0.97       471
#      Sitting       0.96      1.00      0.98       420
#     Standing       0.93      0.66      0.77       491
#     Upstairs       0.76      0.95      0.85       532
#      Walking       0.99      1.00      1.00       537
#
#     accuracy                           0.93      2947
#    macro avg       0.94      0.93      0.92      2947
# weighted avg       0.93      0.93      0.92      2947
#
# Train_accuracy 0.9256871342658997
# validation accuracy 0.9256871342658997
#
# gBest model loss in the test set: 0.408192794910317 - Test set accuracy: 0.9256871342658997
# This run took: 2760.827569961548 seconds.
# All gBest number of parameters: [2549719]
# All gBest test accuracies: [0.92568713]
# All running times: [2760.827569961548]
# Mean loss of all runs: 0.408192794910317
# Mean accuracy of all runs: 0.9256871342658997
